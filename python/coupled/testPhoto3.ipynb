# %%
# %load_ext autoreload
# %autoreload 2
import sys; 
CPBdir = "../../../../cpb1104/CPlantBox"
sys.path.append(CPBdir+"/src");
sys.path.append(CPBdir);
sys.path.append("../../..");sys.path.append(".."); 
sys.path.append(CPBdir+"/src/python_modules");
sys.path.append("../build-cmake/cpp/python_binding/") # dumux python binding
sys.path.append("../../build-cmake/cpp/python_binding/")
sys.path.append("../modules/") # python wrappers 
#import reload
from helpuqrMasterCopy1 import *
from helpuqrMasterCopy1 import setKrKx_xylem
#reload(helpuqrMasterCopy1)
import numpy as np
directoryN="/testPhoto3/"


def weather(simDuration, hp,condition):
    vgSoil = [0.059, 0.45, 0.00644, 1.503, 1]
    loam = [0.08, 0.43, 0.04, 1.6, 50]
    Qnigh = 0; Qday = 960e-6 #458*2.1
    if (condition == "wet"):
        Tnigh = 15.8; Tday = 22
        #Tnigh = 13; Tday = 20.7
        #specificHumidity = 0.0097
        RHday = 0.60; RHnigh = 0.88
        Pair = 1010.00 #hPa
        thetaInit = 40/100#15.59/100#
        cs = 350e-6
    elif condition == "dry":
        Tnigh = 20.7; Tday = 30.27
        #Tnigh = 15.34; Tday = 23.31
        #specificHumidity = 0.0097# 0.0111
        RHday = 0.3; RHnigh = 0.78
        Pair = 1070.00 #hPa
        thetaInit = 28/100#10.47/100#   
        cs = 350e-6
    else:
        print("condition",condition)
        raise Exception("condition not recognised")
    coefhours = sinusoidal(simDuration)
    RH_ = RHnigh + (RHday - RHnigh) * coefhours
    TairC_ = Tnigh + (Tday - Tnigh) * coefhours
    Q_ = Qnigh + (Qday - Qnigh) * coefhours
     #co2 paartial pressure at leaf surface (mol mol-1)
    #390, 1231
    #RH = 0.5 # relative humidity
    es =  6.112 * np.exp((17.67 * TairC_)/(TairC_ + 243.5))
    ea = es*RH_#qair2ea(specificHumidity,  Pair)
    assert ea < es
    #RH = ea/es
    assert ((RH_ > 0) and(RH_ < 1))
    bl_thickness = 1/1000 #m
    diffusivity= 2.5e-5#m2/sfor 25°C
    rbl =bl_thickness/diffusivity #s/m 13
    #cs = 350e-6
    Kcanopymean = 1e-1 # m2/s
    meanCanopyL = (2/3) * hp /2
    rcanopy = meanCanopyL/Kcanopymean
    windSpeed = 2 #m/s
    zmzh = 2 #m
    karman = 0.41 #[-]

    rair = 1
    if hp > 0:
        rair = np.log((zmzh - (2/3)*hp)/(0.123*hp)) * np.log((zmzh - (2/3)*hp)/(0.1*hp)) / (karman*karman*windSpeed)
        #print()
        #raise Exception


    pmean = theta2H(vgSoil, thetaInit)

    weatherVar = {'TairC' : TairC_,'TairK' : TairC_ + 273.15,'Pair':Pair,"es":es,
                    'Qlight': Q_,'rbl':rbl,'rcanopy':rcanopy,'rair':rair,"ea":ea,
                    'cs':cs, 'RH':RH_, 'p_mean':pmean, 'vg':loam}
    #print("Env variables at", round(simDuration//1),"d",round((simDuration%1)*24),"hrs :\n", weatherVar)
    return weatherVar
def resistance2conductance(resistance,r,weatherX):
    resistance = resistance* (1/100) #[s/m] * [m/cm] = [s/cm]
    resistance = resistance * r.R_ph * weatherX["TairK"] / r.Patm # [s/cm] * [K] * [hPa cm3 K−1 mmol−1] * [hPa] = [s] * [cm2 mmol−1]
    resistance = resistance * (1000) * (1/10000)# [s cm2 mmol−1] * [mmol/mol] * [m2/cm2] = [s m2 mol−1]
    return 1/resistance

def initPlant(simDuration, condition):
    weatherInit = weather(0,0, condition)
    #simDuration = 25 # [day] init simtime
    #spellDuration = 5
    simMax = 26#simStartSim+ spellDuration
    depth = 40
    dt = 1/24 #10min
    verbose = True

    # plant system 
    pl = pb.MappedPlant(seednum = 2) #pb.MappedRootSystem() #pb.MappedPlant()
    #pl2 = pb.MappedPlant(seednum = 2) #pb.MappedRootSystem() #pb.MappedPlant()
    path = CPBdir+"/modelparameter/plant/"
    name = "Triticum_aestivum_test_2021"#"Triticum_aestivum_adapted_2021"#

    pl.readParameters(path + name + ".xml")
    #pl2.readParameters(path + name + ".xml")



    #raise Exception
    sdf = pb.SDF_PlantBox(np.Inf, np.Inf, depth )

    pl.setGeometry(sdf) # creates soil space to stop roots from growing out of the soil
    #pl2.setGeometry(sdf) # creates soil space to stop roots from growing out of the soil


    pl.initialize(verbose = True)#, stochastic = False)
    pl.simulate(simDuration, False)#, "outputpm15.txt")

    #raise Exception
    """ Coupling to soil """



    min_b = [-3./2, -12./2, -41.]#distance between wheat plants
    max_b = [3./2, 12./2, 0.]
    rez = 0.5
    cell_number = [int(6*rez), int(24*rez), int(40*rez)]#1cm3? 
    layers = depth; soilvolume = (depth / layers) * 3 * 12
    k_soil = []
    initial = weatherInit["p_mean"]#mean matric potential [cm] pressure head

    p_mean = initial
    p_bot = p_mean + depth/2
    p_top = initial - depth/2
    sx = np.linspace(p_top, p_bot, depth)
    picker = lambda x,y,z : max(int(np.floor(-z)),-1) 
    sx_static_bu = sx    
    pl.setSoilGrid(picker)  # maps segment



    """ Parameters phloem and photosynthesis """
    r = PhloemFluxPython(pl,psiXylInit = min(sx),ciInit = weatherInit["cs"]*0.5) #XylemFluxPython(pl)#
    #r2 = PhloemFluxPython(#pl2,psiXylInit = min(sx),ciInit = weatherInit["cs"]*0.5) #XylemFluxPython(pl)#
    

    r = setKrKx_phloem(r)

    r.oldciEq = True

    r.Rd_ref = 0 #to avoid error (C < 0 in meso, mention this in paper)
    r.g0 = 8e-3
    r.VcmaxrefChl1 =1.28
    r.VcmaxrefChl2 = 8.33
    r.a1 = 0.6/0.4#0.7/0.3#0.6/0.4 #ci/(cs - ci) for ci = 0.6*cs
    r.a3 = 1.5
    r.alpha = 0.4#0.2#/2
    r.theta = 0.6#0.9#/2
    r.k_meso = 1e-3#1e-4
    r.setKrm2([[2e-5]])
    r.setKrm1([[10e-2]])#([[2.5e-2]])
    r.setRhoSucrose([[0.51],[0.65],[0.56]])#0.51
    #([[14.4,9.0,0,14.4],[5.,5.],[15.]])
    rootFact = 2
    r.setRmax_st([[2.4*rootFact,1.5*rootFact,0.6*rootFact,2.4*rootFact],[2.,2.],[8.]])#6.0#*6 for roots, *1 for stem, *24/14*1.5 for leaves
    #r.setRmax_st([[12,9.0,6.0,12],[5.,5.],[15.]])
    r.KMrm = 0.1#VERY IMPORTANT TO KEEP IT HIGH
    #r.exud_k = np.array([2.4e-4])#*10#*(1e-1)
    #r.k_gr = 1#0
    r.sameVolume_meso_st = False
    r.sameVolume_meso_seg = True
    r.withInitVal =True
    r.initValST = 0.#0.6#0.0
    r.initValMeso = 0.#0.9#0.0
    r.beta_loading = 0.6
    r.Vmaxloading = 0.05 #mmol/d, needed mean loading rate:  0.3788921068507634
    r.Mloading = 0.2
    r.Gr_Y = 0.8
    r.CSTimin = 0.4
    r.surfMeso=0.0025
    r.leafGrowthZone = 2 # cm
    r.StemGrowthPerPhytomer = True # 
    r.psi_osmo_proto = -10000*1.0197 #schopfer2006
    r.fwr = 0

    r.cs = weatherInit["cs"]

    #r.r_forPhloem(24/14*1.5, 4)
    #r.r_forPhloem(24/14, 3)
    #r.r_forPhloem(6, 2) #because roots will have high C_ST less often
    r.expression = 6
    r.update_viscosity = True
    r.solver = 1
    r.atol = 1e-10
    r.rtol = 1e-6
    #r.doNewtonRaphson = False;r.doOldEq = False
    SPAD= 41.0
    chl_ = (0.114 *(SPAD**2)+ 7.39 *SPAD+ 10.6)/10
    r.Chl = np.array( [chl_]) 
    r.Csoil = 1e-4
    
    hp = max([tempnode[2] for tempnode in r.get_nodes()]) /100 

    weatherX = weather(simDuration, hp,condition)
    r.Patm = weatherX["Pair"]
    ##resistances
    r.g_bl = resistance2conductance(weatherX["rbl"],r,weatherX) / r.a2_bl
    r.g_canopy = resistance2conductance(weatherX["rcanopy"],r,weatherX) / r.a2_canopy
    r.g_air = resistance2conductance(weatherX["rair"],r,weatherX) / r.a2_air
    r.sh = 4e-4
    r.fwr = 0#0.001
    r.shmesophyll = 4e-4
    r.fwrmesophyll = 0#0.001
    r.p_lcritmesophyll=-100000
    #r.gm = 0.05
    r.g0 = 8e-6
    r.alternativeAn = False
    r.limMaxErr = 1/100;

    r.Qlight = weatherX["Qlight"] #; TairC = weatherX["TairC"] ; text = "night"
    kr_l  = 3.83e-5 
    r = setKrKx_xylem(weatherX["TairC"], weatherX["RH"],r,kr_l)
    kr_l  = 3.83e-5
    #r.setKr_meso([kr_l]) 
    r.es = weatherX["es"]
    return r, weatherX, sx
simDuration = 10
rinit=initPlant(simDuration, condition="wet")
r = rinit[0]
weatherX = rinit[1] 
sx =rinit[2]#np.linspace(-100, -20000, 100)
p_errors =[]
r.usePg4Fw = False
dt=1/24
while simDuration <= 11:
    hp = max([tempnode[2] for tempnode in r.get_nodes()]) /100 #maxnode canopy [m]
    #print([tempnode[2] for tempnode in r.get_nodes()], hp)

    weatherX = weather(simDuration, hp,"wet")
    r.Patm = weatherX["Pair"]
    ##resistances
    r.g_bl = resistance2conductance(weatherX["rbl"],r,weatherX) / r.a2_bl
    r.g_canopy = resistance2conductance(weatherX["rcanopy"],r,weatherX) / r.a2_canopy
    r.g_air = resistance2conductance(weatherX["rair"],r,weatherX) / r.a2_air

    r.Qlight = weatherX["Qlight"] #; TairC = weatherX["TairC"] ; text = "night"
    kr_l = 3.83e-5
    r = setKrKx_xylem(weatherX["TairC"], weatherX["RH"],r,kr_l)
    
    #kr_l  = 3.83e-7
    #r.setKr_meso([kr_l]) 
    r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                    verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
    startphloem= simDuration
    endphloem = startphloem + dt
    stepphloem = 1
    filename = "results"+ directoryN +"inPM_"+str(0)+".txt"
    r.startPM(startphloem, endphloem, stepphloem, ( weatherX["TairC"]  +273.15) , False, filename)
    r.plant.simulate(dt, False)
    try:
        os.remove(filename)
    except OSError:
        pass   
    simDuration += dt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# MappedPlant::initialize
# Seed::initialize: Plant
# Seed::initialize: Basal root type #4 was not defined, using tap root parameters instead
# Tiller stem type #4 was not defined, using main stem parameters instead, Exchange zone in roots: kr_st > 0 until 0.8cm from root tip 1 1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr_st is constant per subtype of organ type, for root, subtype 1 = 0.05 1 day-1
# Kx_st is constant per subtype of organ type, for root, subtype 1 = 1.32591e-13 cm3 day-1
# Across_st is constant per subtype of organ type, for root, subtype 1 = 9.62113e-06 cm2
# krm2 is constant 2e-05 -
# krm1 is constant 0.1 -
# rhoSucrose is constant per organ type, organ type 2 (root) = 0.51 mmol cm-3
# Rmax_st is constant per subtype of organ type, for root, subtype 1 = 3 cm day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Output times :
#  10 10.0417
# starting integration on time segment #1 = [10, 10.0417] 2 2
# at t = 10 : Y0.size() = 1116
# at 13:31:17 :  starting step n#1 (tf = 10.0417)
# at t = 10.0417 : Y0.size() = 1116
#
# Final Statistics:
# nst (num steps) = 826    nfe  (num call to f)= 1542   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1539   ncfn (non linsolver conv fail)= 335    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0692154 cm3 day-1
# Output times :
#  10.0417 10.0833
# starting integration on time segment #1 = [10.0417, 10.0833] 2 2
# at t = 10.0417 : Y0.size() = 1116
# at 13:31:17 :  starting step n#1 (tf = 10.0833)
# at t = 10.0833 : Y0.size() = 1116
#
# Final Statistics:
# nst (num steps) = 1528   nfe  (num call to f)= 2959   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2956   ncfn (non linsolver conv fail)= 710    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0705129 cm3 day-1
# Output times :
#  10.0833 10.125
# starting integration on time segment #1 = [10.0833, 10.125] 2 2
# at t = 10.0833 : Y0.size() = 1116
# at 13:31:17 :  starting step n#1 (tf = 10.125)
# at t = 10.125 : Y0.size() = 1116
#
# Final Statistics:
# nst (num steps) = 1083   nfe  (num call to f)= 2101   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2098   ncfn (non linsolver conv fail)= 500    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0716323 cm3 day-1
# Output times :
#  10.125 10.1667
# starting integration on time segment #1 = [10.125, 10.1667] 2 2
# at t = 10.125 : Y0.size() = 1116
# at 13:31:17 :  starting step n#1 (tf = 10.1667)
# at t = 10.1667 : Y0.size() = 1116
#
# Final Statistics:
# nst (num steps) = 795    nfe  (num call to f)= 1493   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1490   ncfn (non linsolver conv fail)= 340    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0724945 cm3 day-1
# Output times :
#  10.1667 10.2083
# starting integration on time segment #1 = [10.1667, 10.2083] 2 2
# at t = 10.1667 : Y0.size() = 1116
# at 13:31:17 :  starting step n#1 (tf = 10.2083)
# at t = 10.2083 : Y0.size() = 1116
#
# Final Statistics:
# nst (num steps) = 970    nfe  (num call to f)= 1840   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1837   ncfn (non linsolver conv fail)= 425    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0730379 cm3 day-1
# Output times :
#  10.2083 10.25
# starting integration on time segment #1 = [10.2083, 10.25] 2 2
# at t = 10.2083 : Y0.size() = 1134
# at 13:31:17 :  starting step n#1 (tf = 10.25)
# at t = 10.25 : Y0.size() = 1134
#
# Final Statistics:
# nst (num steps) = 1609   nfe  (num call to f)= 3024   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 3021   ncfn (non linsolver conv fail)= 693    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0732234 cm3 day-1
# Output times :
#  10.25 10.2917
# starting integration on time segment #1 = [10.25, 10.2917] 2 2
# at t = 10.25 : Y0.size() = 1161
# at 13:31:17 :  starting step n#1 (tf = 10.2917)
# at t = 10.2917 : Y0.size() = 1161
#
# Final Statistics:
# nst (num steps) = 844    nfe  (num call to f)= 1483   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1480   ncfn (non linsolver conv fail)= 305    netf (num err test fail) = 2      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0730379 cm3 day-1
# Output times :
#  10.2917 10.3333
# starting integration on time segment #1 = [10.2917, 10.3333] 2 2
# at t = 10.2917 : Y0.size() = 1170
# at 13:31:17 :  starting step n#1 (tf = 10.3333)
# at t = 10.3333 : Y0.size() = 1170
#
# Final Statistics:
# nst (num steps) = 1206   nfe  (num call to f)= 2302   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2299   ncfn (non linsolver conv fail)= 535    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0724945 cm3 day-1
# Output times :
#  10.3333 10.375
# starting integration on time segment #1 = [10.3333, 10.375] 2 2
# at t = 10.3333 : Y0.size() = 1179
# at 13:31:17 :  starting step n#1 (tf = 10.375)
# at t = 10.375 : Y0.size() = 1179
#
# Final Statistics:
# nst (num steps) = 1075   nfe  (num call to f)= 1993   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1990   ncfn (non linsolver conv fail)= 446    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0716323 cm3 day-1
# Output times :
#  10.375 10.4167
# starting integration on time segment #1 = [10.375, 10.4167] 2 2
# at t = 10.375 : Y0.size() = 1197
# at 13:31:17 :  starting step n#1 (tf = 10.4167)
# at t = 10.4167 : Y0.size() = 1197
#
# Final Statistics:
# nst (num steps) = 900    nfe  (num call to f)= 1726   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1723   ncfn (non linsolver conv fail)= 399    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0705129 cm3 day-1
# Output times :
#  10.4167 10.4583
# starting integration on time segment #1 = [10.4167, 10.4583] 2 2
# at t = 10.4167 : Y0.size() = 1206
# at 13:31:17 :  starting step n#1 (tf = 10.4583)
# at t = 10.4583 : Y0.size() = 1206
#
# Final Statistics:
# nst (num steps) = 1546   nfe  (num call to f)= 2882   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2880   ncfn (non linsolver conv fail)= 657    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0692154 cm3 day-1
# Output times :
#  10.4583 10.5
# starting integration on time segment #1 = [10.4583, 10.5] 2 2
# at t = 10.4583 : Y0.size() = 1224
# at 13:31:17 :  starting step n#1 (tf = 10.5)
# at t = 10.5 : Y0.size() = 1224
#
# Final Statistics:
# nst (num steps) = 1278   nfe  (num call to f)= 2377   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2374   ncfn (non linsolver conv fail)= 537    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Output times :
#  10.5 10.5417
# starting integration on time segment #1 = [10.5, 10.5417] 2 2
# at t = 10.5 : Y0.size() = 1242
# at 13:31:17 :  starting step n#1 (tf = 10.5417)
# at t = 10.5417 : Y0.size() = 1242
#
# Final Statistics:
# nst (num steps) = 649    nfe  (num call to f)= 1160   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1157   ncfn (non linsolver conv fail)= 244    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0664536 cm3 day-1
# Output times :
#  10.5417 10.5833
# starting integration on time segment #1 = [10.5417, 10.5833] 2 2
# at t = 10.5417 : Y0.size() = 1260
# at 13:31:17 :  starting step n#1 (tf = 10.5833)
# at t = 10.5833 : Y0.size() = 1260
#
# Final Statistics:
# nst (num steps) = 755    nfe  (num call to f)= 1408   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1405   ncfn (non linsolver conv fail)= 316    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0651778 cm3 day-1
# Output times :
#  10.5833 10.625
# starting integration on time segment #1 = [10.5833, 10.625] 2 2
# at t = 10.5833 : Y0.size() = 1305
# at 13:31:17 :  starting step n#1 (tf = 10.625)
# at t = 10.625 : Y0.size() = 1305
#
# Final Statistics:
# nst (num steps) = 1015   nfe  (num call to f)= 1794   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1791   ncfn (non linsolver conv fail)= 374    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0640881 cm3 day-1
# Output times :
#  10.625 10.6667
# starting integration on time segment #1 = [10.625, 10.6667] 2 2
# at t = 10.625 : Y0.size() = 1305
# at 13:31:17 :  starting step n#1 (tf = 10.6667)
# at t = 10.6667 : Y0.size() = 1305
#
# Final Statistics:
# nst (num steps) = 956    nfe  (num call to f)= 1797   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1794   ncfn (non linsolver conv fail)= 413    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0632556 cm3 day-1
# Output times :
#  10.6667 10.7083
# starting integration on time segment #1 = [10.6667, 10.7083] 2 2
# at t = 10.6667 : Y0.size() = 1323
# at 13:31:17 :  starting step n#1 (tf = 10.7083)
# at t = 10.7083 : Y0.size() = 1323
#
# Final Statistics:
# nst (num steps) = 1312   nfe  (num call to f)= 2496   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2493   ncfn (non linsolver conv fail)= 577    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.062734 cm3 day-1
# Output times :
#  10.7083 10.75
# starting integration on time segment #1 = [10.7083, 10.75] 2 2
# at t = 10.7083 : Y0.size() = 1350
# at 13:31:17 :  starting step n#1 (tf = 10.75)
# at t = 10.75 : Y0.size() = 1350
#
# Final Statistics:
# nst (num steps) = 726    nfe  (num call to f)= 1352   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1349   ncfn (non linsolver conv fail)= 299    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0625564 cm3 day-1
# Output times :
#  10.75 10.7917
# starting integration on time segment #1 = [10.75, 10.7917] 2 2
# at t = 10.75 : Y0.size() = 1368
# at 13:31:17 :  starting step n#1 (tf = 10.7917)
# at t = 10.7917 : Y0.size() = 1368
#
# Final Statistics:
# nst (num steps) = 1322   nfe  (num call to f)= 2426   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2424   ncfn (non linsolver conv fail)= 535    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.062734 cm3 day-1
# Output times :
#  10.7917 10.8333
# starting integration on time segment #1 = [10.7917, 10.8333] 2 2
# at t = 10.7917 : Y0.size() = 1377
# at 13:31:17 :  starting step n#1 (tf = 10.8333)
# at t = 10.8333 : Y0.size() = 1377
#
# Final Statistics:
# nst (num steps) = 1376   nfe  (num call to f)= 2612   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2609   ncfn (non linsolver conv fail)= 604    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0632556 cm3 day-1
# Output times :
#  10.8333 10.875
# starting integration on time segment #1 = [10.8333, 10.875] 2 2
# at t = 10.8333 : Y0.size() = 1404
# at 13:31:17 :  starting step n#1 (tf = 10.875)
# at t = 10.875 : Y0.size() = 1404
#
# Final Statistics:
# nst (num steps) = 879    nfe  (num call to f)= 1599   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1596   ncfn (non linsolver conv fail)= 347    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0640881 cm3 day-1
# Output times :
#  10.875 10.9167
# starting integration on time segment #1 = [10.875, 10.9167] 2 2
# at t = 10.875 : Y0.size() = 1440
# at 13:31:17 :  starting step n#1 (tf = 10.9167)
# at t = 10.9167 : Y0.size() = 1440
#
# Final Statistics:
# nst (num steps) = 718    nfe  (num call to f)= 1356   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1353   ncfn (non linsolver conv fail)= 306    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0651778 cm3 day-1
# Output times :
#  10.9167 10.9583
# starting integration on time segment #1 = [10.9167, 10.9583] 2 2
# at t = 10.9167 : Y0.size() = 1458
# at 13:31:17 :  starting step n#1 (tf = 10.9583)
# at t = 10.9583 : Y0.size() = 1458
#
# Final Statistics:
# nst (num steps) = 832    nfe  (num call to f)= 1505   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1503   ncfn (non linsolver conv fail)= 324    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0664536 cm3 day-1
# Output times :
#  10.9583 11
# starting integration on time segment #1 = [10.9583, 11] 2 2
# at t = 10.9583 : Y0.size() = 1494
# at 13:31:17 :  starting step n#1 (tf = 11)
# at t = 11 : Y0.size() = 1494
#
# Final Statistics:
# nst (num steps) = 905    nfe  (num call to f)= 1644   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1641   ncfn (non linsolver conv fail)= 358    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Output times :
#  11 11.0417
# starting integration on time segment #1 = [11, 11.0417] 2 2
# at t = 11 : Y0.size() = 1503
# at 13:31:17 :  starting step n#1 (tf = 11.0417)
# at t = 11.0417 : Y0.size() = 1503
#
# Final Statistics:
# nst (num steps) = 1143   nfe  (num call to f)= 2049   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2046   ncfn (non linsolver conv fail)= 438    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 13:31:17 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth

# %%
rootLength = np.array([mr.getLength(False) for mr in r.plant.getOrgans(2, False)])
st4leng = np.array([mr.getParameter("subType") for mr in r.plant.getOrgans(2, False)])
root1Length = sum([mr.getLength(False)*((mr.getParameter("subType")==1)or(mr.getParameter("subType")==4)) for mr in r.plant.getOrgans(2, False)])
root2Length = sum([mr.getLength(False)*((mr.getParameter("subType")==2))  for mr in r.plant.getOrgans(2, False)])
root3Length = sum([mr.getLength(False)*((mr.getParameter("subType")==3))  for mr in r.plant.getOrgans(2, False)])
leafLength = sum([mr.getLength(False) for mr in r.plant.getOrgans(4, False)])
print("root length {:5.2e}\tlef length {:5.2e}".format(sum(rootLength),leafLength))
print("length root1 {:5.2e}\troot2 {:5.2e}\troot3 {:5.2e}".format(root1Length,root2Length,root3Length))

#root length 1.63e+02	lef length 4.40e+01
#length root1 6.29e+01	root2 9.96e+01	root3 0.00e+00
#root length 1.45e+02	lef length 4.69e+01
#length root1 6.63e+01	root2 7.87e+01	root3 0.00e+00
# Out:
# root length 1.45e+02	lef length 4.69e+01
# length root1 6.63e+01	root2 7.87e+01	root3 0.00e+00

# %%
#print(r.k_leaf,r.k_stomatas,r.gco2,r.psi_air,r.pg,r.fwmesophyll)
print(r.fw)
# Out:
# [0.0, 0.0, 0.0, 0.0, 0.9644618224493675, 0.9643938546285362, 0.9643287776369535, 0.964266604448468, 0.964207029999009, 0.964150614775118, 0.9640977469897442, 0.9640477630827313, 0.9640008012538736, 0.0, 0.0, 0.0, 0.0, 0.9645059386157262, 0.9644479824223993, 0.964392622260437, 0.0, 0.9639636665755695, 0.9643427384858787, 0.0]

# %%
def sinusoidal(t):
    return 1#(np.sin(np.pi*t*2)+1)/2 
def weather(simDuration, hp,condition):
    vgSoil = [0.059, 0.45, 0.00644, 1.503, 1]
    loam = [0.08, 0.43, 0.04, 1.6, 50]
    Qnigh = 0; Qday = 960e-6 #458*2.1
    if (condition == "wet"):
        Tnigh = 15.8; Tday = 22
        #Tnigh = 13; Tday = 20.7
        #specificHumidity = 0.0097
        RHday = 0.60; RHnigh = 0.88
        Pair = 1010.00 #hPa
        thetaInit = 40/100#15.59/100#
        cs = 350e-6
    elif condition == "dry":
        Tnigh = 20.7; Tday = 30.27
        #Tnigh = 15.34; Tday = 23.31
        #specificHumidity = 0.0097# 0.0111
        RHday = 0.30; RHnigh = 0.78
        Pair = 1070.00 #hPa
        thetaInit = 28/100#10.47/100#   
        cs = 350e-6
    else:
        print("condition",condition)
        raise Exception("condition not recognised")
    coefhours = sinusoidal(simDuration)
    RH_ = RHnigh + (RHday - RHnigh) * coefhours
    TairC_ = Tnigh + (Tday - Tnigh) * coefhours
    Q_ = Qnigh + (Qday - Qnigh) * coefhours
     #co2 paartial pressure at leaf surface (mol mol-1)
    #390, 1231
    #RH = 0.5 # relative humidity
    es =  6.112 * np.exp((17.67 * TairC_)/(TairC_ + 243.5))
    ea = es*RH_#qair2ea(specificHumidity,  Pair)
    assert ea < es
    #RH = ea/es
    assert ((RH_ > 0) and(RH_ < 1))
    bl_thickness = 1/1000 #m
    diffusivity= 2.5e-5#m2/sfor 25°C
    rbl =bl_thickness/diffusivity #s/m 13
    #cs = 350e-6
    Kcanopymean = 1e-1 # m2/s
    meanCanopyL = (2/3) * hp /2
    rcanopy = meanCanopyL/Kcanopymean
    windSpeed = 2 #m/s
    zmzh = 2 #m
    karman = 0.41 #[-]

    rair = 1
    if hp > 0:
        rair = np.log((zmzh - (2/3)*hp)/(0.123*hp)) * np.log((zmzh - (2/3)*hp)/(0.1*hp)) / (karman*karman*windSpeed)
        #print()
        #raise Exception


    pmean = theta2H(vgSoil, thetaInit)

    weatherVar = {'TairC' : TairC_,'TairK' : TairC_ + 273.15,'Pair':Pair,"es":es,
                    'Qlight': Q_,'rbl':rbl,'rcanopy':rcanopy,'rair':rair,"ea":ea,
                    'cs':cs, 'RH':RH_, 'p_mean':pmean, 'vg':loam}
    #print("Env variables at", round(simDuration//1),"d",round((simDuration%1)*24),"hrs :\n", weatherVar)
    return weatherVar

# %%
#test effect of watpot
#simDuration = 12.166666666666636#12.208333333333302
#print(weather(simDuration, hp,"dry"))
simDuration = 12.208333333333302
weatherX = weather(simDuration, hp,"dry")
#print(weatherX)
#raise Exception
#print(weatherX)
#raise Exception

testPsoil = np.linspace(-15000, -500,500)#np.array([-4742.48496993988,-4713.426853707415])#
#np.linspace(-15000, -500,500)#
#np.array([-9854.454454454455,-9853.353353353354])#np.linspace(-10100, -9000,1000)

EvRate = []
Ev = []
An = []
Vc = []
Vj = []
Anrate = []
Vcrate = []
Vjrate = []
gco2 = []
ci = []
fw = []
fwold = []
fwVold = []
pg = []
pl = []
k_stomatas = []
loop=[]

psiXylBU=np.full(len(r.psiXyl),-1000)
pgBU =np.full(len(r.pg),-1000)
r.Theta_ag = 0.8#1#0.7
#print(r.useVj)

r.p_lcrit=-10000
#r.p_lcritmesophyll=-10000
#

r.limMaxErr = 1/100
r.gm=0.1
r.g0=0
r.fwr=0
r.a1=1.5#6
r.minLoop=100
r.VcmaxrefChl1 =1.28*2#/4
r.VcmaxrefChl2 = 8.33*2#/4
r.loop=1
#directoryN="/testPhoto3/"
testPsoiLight = np.linspace(0,1,500)
#for i, lightI in enumerate(testPsoiLight):#while not stop:
for i, p_mean in enumerate(testPsoil):#while not stop:
    depth=60
    #print(i, p_mean)
    #print(i, lightI)
    #p_mean = -600
    p_bot = p_mean + depth/2
    p_top = p_mean - depth/2
    sx = np.linspace(p_top, p_bot, depth)
    
    hp = max([tempnode[2] for tempnode in r.get_nodes()]) /100 #maxnode canopy [m]
    #print([tempnode[2] for tempnode in r.get_nodes()], hp)

    weatherX = weather(simDuration, hp,"dry")
    r.Patm = weatherX["Pair"]
    ##resistances
    r.g_bl = resistance2conductance(weatherX["rbl"],r,weatherX) / r.a2_bl
    r.g_canopy = resistance2conductance(weatherX["rcanopy"],r,weatherX) / r.a2_canopy
    r.g_air = resistance2conductance(weatherX["rair"],r,weatherX) / r.a2_air

    r.Qlight = weatherX["Qlight"]#*lightI#; TairC = weatherX["TairC"] ; text = "night"
    kr_l  = 3.83e-3


    r = setKrKx_xylem(weatherX["TairC"], weatherX["RH"],r,kr_l)
    
    
    success = False
    
    #r.psiXyl = np.full(len(r.psiXyl),-1000)#psiXylBU#
    #r.pg = np.full(len(r.pg),-1000)#pgBU #
    r.loop=0
    r.maxLoop=1000
    r.followTrace = False
    try:
        r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                        verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
    except:
        print("r.solve_photosynthesis(","./results"+directoryN)
        r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                        verbose_ = True, doLog_ = True,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
        print(r.fw, r.Ev)
        raise Exception
        print("photosynthesis::solve: did not reach convergence")
        success = False
            
    print("numLoop ",r.loop)
    leaf_nodes = r.get_nodes_index(4)
    if True:#success
        loop.append(r.loop)
        Ev.append(sum(r.Ev))
        An.append(sum(r.An)*1e6)
        Vc.append(sum(r.Vc)*1e6)
        Vj.append(sum(r.Vj)*1e6)
        Anrate.append(np.mean(np.array(r.An)[np.array(r.ci) >0])*1e6)
        Vcrate.append(np.mean(np.array(r.Vc)[np.array(r.ci) >0])*1e6)
        Vjrate.append(np.mean(np.array(r.Vj)[np.array(r.ci) >0])*1e6)
        
        EvRate.append(np.mean(np.array(r.Jw)[np.array(r.ci) >0]))
        gco2.append(np.mean(np.array(r.gco2)[np.array(r.ci) >0]))
        ci.append(np.mean(np.array(r.ci)[np.array(r.ci) >0]))
        fw.append(np.mean(np.array(r.fw)[np.array(r.ci) >0]))
        #fwold.append(np.mean(np.array(r.fw_old)[np.array(r.ci) >0]))
        #fwVold.append(np.mean(np.array(r.fw_very_old)[np.array(r.ci) >0]))
        pg.append(np.mean(np.array(r.pg)[np.array(r.ci) >0]))
        #pl.append(np.mean(np.array(r.psiXyl)[leaf_nodes][np.array(r.ci) >0]))
        #k_stomatas.append(np.mean(np.array(r.k_stomatas)[np.array(r.ci) >0]))
    else:
        Ev.append(np.nan)
        An.append(np.nan)
        Vc.append(np.nan)
        Vj.append(np.nan)
        gco2.append(np.nan)
        ci.append(np.nan)
        fw.append(np.mean(np.array(r.fw)[np.array(r.ci) >0]))
        #fwold.append(np.mean(np.array(r.fw_old)[np.array(r.ci) >0]))
        #fwVold.append(np.mean(np.array(r.fw_very_old)[np.array(r.ci) >0]))
        pg.append(np.nan)
        #pl.append(np.nan)
        #k_stomatas.append(np.nan)

print("finised test")
# Out:
# numLoop  754
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  753
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  752
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  751
# numLoop  750
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  749
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  749
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  748
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  747
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  746
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  745
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  744
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  743
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  742
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  741
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  740
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  740
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  739
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  738
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  737
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  736
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  735
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  734
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  733
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  733
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  732
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  731
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  730
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  729
# numLoop  728
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  728
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  727
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  726
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  725
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  724
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  723
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  723
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  722
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  721
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  720
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  719
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  718
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  718
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  717
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  716
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  715
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  714
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  714
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  713
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  712
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  711
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  711
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  710
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  709
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  708
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  707
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  707
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  706
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  705
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  704
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  704
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  703
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  702
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  701
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  701
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  700
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  699
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  698
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  698
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  697
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  696
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  695
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  695
# numLoop  Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# 694
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  693
# numLoop  693
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  692
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  691
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  690
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  690
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  689
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  688
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  688
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  687
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  686
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  686
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  685
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  684
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  683
# numLoop  683
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  682
# numLoop  681
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  681
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  680
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  679
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  679
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  678
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  677
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  677
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  676
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  675
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  675
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  674
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  673
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  673
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  672
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  672
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  671
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  670
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  670
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  669
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  668
# numLoop  668
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  667
# numLoop  666Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  666
# numLoop  665
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  665
# numLoop Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#  664
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  663
# numLoop  663
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  662
# numLoop  662
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  661
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  660
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  660
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  659
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  659
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  658
# numLoop  657
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  657
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  656
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  656
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  655
# numLoop  654
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  654
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  653
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  653
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  652
# numLoop  Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# 652
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  651
# numLoop  650
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  650
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  649
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  649
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  648
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  648
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  647
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  647
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  646
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  645
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  645
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  644
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  644
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  643
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  643
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  642
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  642
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  641
# numLoop  641
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  640
# numLoop  640
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  639
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  639
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  638
# numLoop  638Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  637
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  636
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  636
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  635
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  635
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  634
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  634
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  633
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  633
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  632
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  632
# numLoop  631
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  631
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  630
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  630
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  630
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  629
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  629
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  628
# numLoop Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#  628
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  627
# numLoop  627
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  626
# numLoop  626
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  625
# numLoop  625
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  624
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  624
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  623
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  623
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  622
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  622
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  622
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  621
# ...
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  553
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  552
# numLoop  552
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  552
# numLoop  552
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  552
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  552
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  551
# numLoop  551
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  551
# numLoop Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#  551
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  551
# numLoop  551
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  551
# numLoop Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#  550
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  550
# numLoop  550
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  550
# numLoop  550
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  550
# numLoop  549
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  549
# numLoop  549
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  549
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  549
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  549
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  549
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  548
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  548
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  548
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  548
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  548
# numLoop Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
#  548
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  548
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  547
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  546
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# numLoop  544
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  544
# finised test

# %%
# !pwd
# Out:
# /home/m.giraud/DUMUX/dumux-rosi/python/coupled

# %%
#psibu2 = np.array(r.psiXyl)
#weatherX=weather(simDuration, hp,"wet")
r.maxLoop = 1000
#r.minLoop=900
r.gm=0.05
#try
r.followTrace = True
#r.p_lcrit=-10000
r.a1=0.16
#r.Rd_ref = 0.32e-6
r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                        verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
#except:
 #   psibu3 =np.array(r.psiXyl)
print(r.gco2,r.fw,sum(r.Ev),r.pg)
#print(sum(r.Ev),np.array(r.An)*1e6,np.array(r.An)*1e6/np.array(r.Jw)/1000/( 18/1000 * 24. * 3600 * 1e-4),r.fw,r.pg,np.array(r.ci)/r.cs)
#print(np.array(r.Vc)*1e6,np.array(r.Vj)*1e6)#,r.Vcmax)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 11
#       9 r.a1=0.16
#      10 #r.Rd_ref = 0.32e-6
# ---> 11 r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
#      12                         verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
#      13 #except:
#      14  #   psibu3 =np.array(r.psiXyl)
#      15 print(r.gco2,r.fw,sum(r.Ev),r.pg)
#
# RuntimeError: photosynthesis::solve: did not reach convergence

# %%
print(np.array(r.ci) -np.array(r.deltagco2),np.array(r.Vcrefmax)*1e6,np.array(r.Jrefmax)*1e6,(r.VcmaxrefChl1*r.Chl[0]+r.VcmaxrefChl2)*1e-6, r.An)
# Out:
# [-4.51651581e-05 -4.51651581e-05 -4.51651581e-05 -4.51651581e-05
#   2.25602188e-04  2.25585535e-04  2.25568784e-04  2.25551948e-04
#   2.25535043e-04  2.25518087e-04  2.25501097e-04  2.25484087e-04
#   2.25467070e-04 -4.51651581e-05 -4.51651581e-05 -4.51651581e-05
#  -4.51651581e-05  2.25594089e-04  2.25575615e-04  2.25557093e-04
#  -4.51651581e-05  2.25542548e-04  2.25454159e-04] [145.997344 145.997344 145.997344 145.997344 145.997344 145.997344
#  145.997344 145.997344 145.997344 145.997344 145.997344 145.997344
#  145.997344 145.997344 145.997344 145.997344 145.997344 145.997344
#  145.997344 145.997344 145.997344 145.997344 145.997344] [218.996016 218.996016 218.996016 218.996016 218.996016 218.996016
#  218.996016 218.996016 218.996016 218.996016 218.996016 218.996016
#  218.996016 218.996016 218.996016 218.996016 218.996016 218.996016
#  218.996016 218.996016 218.996016 218.996016 218.996016] 0.00014599734399999999 [0.0, 0.0, 0.0, 0.0, 2.6000266309586452e-05, 2.5999546104043842e-05, 2.5998821603960106e-05, 2.599809335837634e-05, 2.5997362087351532e-05, 2.5996628521677358e-05, 2.599589341045041e-05, 2.5995157364370515e-05, 2.5994420952852575e-05, 0.0, 0.0, 0.0, 0.0, 2.5999916064266696e-05, 2.59991170555556e-05, 2.599831593394818e-05, 0.0, 2.59976867365047e-05, 2.5993862168609645e-05]

# %%
print(np.array(r.Jw)*1000 *18/1000 * 24. * 3600 * 1e-4)
# Out:
# [ 0.          0.          0.          0.         14.28883074 14.28497439
#  14.28109694 14.27720137 14.27329153 14.26937137 14.2654449  14.26151539
#  14.25758589  0.          0.          0.          0.         14.28695511
#  14.28267794 14.27839178  0.         14.27502707 14.25460551]

# %%
print("./results"+directoryN)
# Out:
# ./results/testPhoto2/success/

# %%
testtest=testPsoil
#testtest= testPsoiLight
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,2, sharey=False)
axs[0, 0].plot(testtest[:len(Ev)], Ev, 'b+')
axs[0, 0].set(xlabel='Ψsoil (cm)', ylabel='total E (cm3/d)')
axs[0, 1].plot(testtest[:len(loop)], loop,'+')
axs[0, 1].set(xlabel='Ψsoil (cm)', ylabel='loop')
axs[1, 0].plot(testtest[:len(Vcrate)], Vcrate, 'g+')
axs[1, 0].plot(testtest[:len(Vjrate)], Vjrate, 'r+')
axs[1,0].plot(testtest[:len(Anrate)],np.array(Anrate),'+')
axs[1, 0].set(xlabel='Ψsoil (cm)', ylabel='An, Vc, Vj mumol m-2 s-1')
axs[1, 1].plot(testtest[:len(pg)], pg, 'g+')
axs[1, 1].set(xlabel='Ψsoil (cm)', ylabel='pg')
plt.show()

# %%
fig, axs = plt.subplots(2,2, sharey=False)
axs[0,0].plot(testtest[:len(gco2)], gco2, 'b+')
axs[0,0].set(xlabel='Ψsoil (cm)', ylabel='gco2')
axs[0,1].plot(testtest[:len(fw)], fw, 'b+')
axs[0,1].set(xlabel='Ψsoil (cm)', ylabel='fw')
#axs[1, 0].plot(testtest[:len(fwold)], np.array(ci)/r.cs, 'r+')
#axs[1, 0].set(xlabel='Ψsoil (cm)', ylabel='ci')
#axs[1,1].plot(testtest[:len(fwVold)],np.array(EvRate)*1000 *18/1000 * 24. * 3600 * 1e-4, 'g+')
#axs[1, 1].set(xlabel='Ψsoil (cm)', ylabel='EvRate mmol m-2 s-1')
plt.show()

# %%
fig, axs = plt.subplots(2,2, sharey=False)
axs[0,0].plot(testtest[:len(gco2)], gco2, 'b+')
axs[0,0].set(xlabel='Ψsoil (cm)', ylabel='gco2')
axs[0,1].plot(testtest[:len(fw)], fw, 'b+')
axs[0,1].set(xlabel='Ψsoil (cm)', ylabel='fw')
axs[1, 0].plot(testtest[:len(fwold)], np.array(ci)/r.cs, 'r+')
axs[1, 0].set(xlabel='Ψsoil (cm)', ylabel='ci')
axs[1,1].plot(testtest[:len(fwVold)],np.array(EvRate)*1000 *18/1000 * 24. * 3600 * 1e-4, 'g+')
axs[1, 1].set(xlabel='Ψsoil (cm)', ylabel='EvRate mmol m-2 s-1')
plt.show()

# %%
testtest=testPsoil
#testtest= testPsoiLight
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,2, sharey=False)
axs[0, 0].plot(testtest[:len(Ev)], Ev, 'b+')
axs[0, 0].set(xlabel='Ψsoil (cm)', ylabel='total E (cm3/d)')
axs[0, 1].plot(testtest[:len(loop)], loop,'+')
axs[0, 1].set(xlabel='Ψsoil (cm)', ylabel='loop')
axs[1, 0].plot(testtest[:len(Vcrate)], Vcrate, 'g+')
axs[1, 0].plot(testtest[:len(Vjrate)], Vjrate, 'r+')
axs[1,0].plot(testtest[:len(Anrate)],np.array(Anrate),'+')
axs[1, 0].set(xlabel='Ψsoil (cm)', ylabel='An, Vc, Vj mumol m-2 s-1')
axs[1, 1].plot(testtest[:len(pg)], pg, 'g+')
axs[1, 1].set(xlabel='Ψsoil (cm)', ylabel='pg')
plt.show()

# %%
 r.psiXyl = np.array(psiXylBU)*Pinit#np.full(len(r.psiXyl),Pinit)#
            r.pg = np.array(pbBU)*Pinit

# %%
r.psiXyl = np.array(psiXylBU)*Pinit#np.full(len(r.psiXyl),Pinit)#
r.pg = np.array(pbBU)*Pinit

# %%
print(r.maxErr,r.maxErrAbs)
# Out:
# [9.930729143756694e-05, 0.00016161917255366897, 0.00026772047730921124, 0.00017394063583665045, 9.913813121420514e-05, 0.0001056273382514751, 0.0, 0.005071798389900789, 0.0022479135289152083] [1.2688333054557006, 2.6336645691984323e-09, 2.009311401328373e-05, 2.3061888426928814e-08, 1.2711830830940016, 3.227491474722122e-05, 0.0, 0.0008152878572289246, 3.67253737385539e-08]
