# %%
import numpy as np
import pickle
from plotnine import *
import pandas as pd

# %%
Sic =np.full(17,0.) 
with open('Sic.pkl','rb') as f:
     Sic = pickle.load(f)['ST']
Sict = Sic.T
print(Sic)
# Out:
# [0.13573917 0.11862909 0.24427665 0.30401461 0.24907585 0.39930685
#  0.46053809 0.36759357 0.58309917 0.63996534 0.54276947 0.66404501
#  0.70039027 0.60128887 0.81547728 0.88195517 0.82972867]

# %%
df = pd.DataFrame(Sict, columns =['Chl','oi','fwr','sh','p_lcrit',
              'VcmaxrefChl1', 'VcmaxrefChl2',
             'a1','a3', 'alpha','theta',
             'gamma0', 'gamma1', 'gamma2','g0',
             'kr','kx'])

# %%
(
    ggplot(df)  # What data to use
    + aes(x='TairC', y= "Chl",color='Qlight'  )  # What variable to use
    + geom_point()  # Geometric object to use for drawing
    + facet_grid(['meanPsi','cs'])
    + xlab("leaf rank")
    + ylab("light interception ratio (-)")
    +theme(legend.text = element_text( size=15),
        legend.title = element_text( size=15),
        legend.position="bottom",#c(0.5,0.1),
        #legend.direction = "horizontal",
        legend.box = "vertical",
        panel.grid.minor = element_line(colour="white"),
        panel.grid.major = element_line(colour="white"),
        panel.background = element_rect(fill="white", color="black"),
        strip.text.y =element_text( size=15) ,
        axis.text = element_text( size=17),
        axis.title = element_text( size=21),
        strip.background = element_rect(fill="white"),
        strip.text.x = element_text(size = 21, hjust = 0,face ="bold"),
        strip.placement = "inside",
        legend.margin=margin()) 
)
# Out:
#   Cell In[66], line 8
#     +theme(legend.text = element_text( size=15),
#            ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
Sic = np.array([np.full(17,0.) for i in range(maxrun)])
for i in range(maxrun):
    with open('Sic_'+repr(i)+'.pkl','rb') as f:
         Sic[i][:] = pickle.load(f)['ST_conf']
Sict = Sic.T
df_conf = pd.DataFrame(Sic, columns =['Chl','oi','fwr','sh','p_lcrit',
              'VcmaxrefChl1', 'VcmaxrefChl2',
             'a1','a3', 'alpha','theta',
             'gamma0', 'gamma1', 'gamma2','g0',
             'kr','kx'])

# %%
df_conf
# Out:
#          Chl        oi       fwr        sh   p_lcrit  VcmaxrefChl1  \
# 0   0.046593  0.045929  0.047704  0.046617  0.053592      0.046741
# 1   0.041682  0.044075  0.042857  0.045616  0.046839      0.047203
# 2   0.041074  0.041595  0.055296  0.046301  0.052603      0.050097
# 3   0.042995  0.042477  0.051121  0.046704  0.054365      0.052419
# 4   0.042831  0.044688  0.050971  0.048931  0.055955      0.047843
# ..       ...       ...       ...       ...       ...           ...
# 76  0.044464  0.043613  0.050834  0.045937  0.053272      0.042570
# 77  0.042493  0.043381  0.049509  0.054145  0.058719      0.046009
# 78  0.040043  0.041182  0.045879  0.043474  0.050905      0.046092
# 79  0.039566  0.039425  0.050645  0.048184  0.052292      0.046718
# 80  0.039869  0.039741  0.051075  0.048346  0.055294      0.055660
#
#     VcmaxrefChl2        a1        a3     alpha     theta    gamma0    gamma1  \
# 0       0.045917  0.044633  0.071981  0.048904  0.047933  0.072168  0.050867
# 1       0.047649  0.042237  0.071198  0.053763  0.053333  0.056661  0.053052
# 1   0.052643  0.058329  0.053113  0.051442
# 2   0.050682  0.057878  0.046485  0.047394
# 3   0.055726  0.065994  0.055448  0.050374
# 4   0.053113  0.045921  0.044883  0.043614
# ..       ...       ...       ...       ...
# 76  0.054746  0.052591  0.040819  0.042330
# 77  0.056807  0.049872  0.047682  0.045986
# 78  0.054221  0.060306  0.046287  0.045315
# 79  0.058950  0.054303  0.044201  0.044928
# 80  0.054814  0.055158  0.042727  0.043925
#
# [81 rows x 17 columns]

# %%
dfmean = pd.DataFrame(data=df_mean.mean(),columns=["mean"])
dfmean["maxst"] = (df_mean + df_conf).max()
dfmean["minst"] = (df_mean - df_conf).min()
dfmean['variables']=dfmean.index
dfmeanVj = dfmean

# %%
(
    ggplot(dfmeanVj)  # What data to use
    + aes(x='variables', y= "mean" )  # What variable to use
    + geom_bar(stat = "identity")  # Geometric object to use for drawing
    + xlab("parameter")
    + geom_errorbar(aes(ymin="minst", ymax="maxst"), width=.2) 
    + ylab("total Sobol sensitivity")
)
# Out:
# <ggplot: (8781413643677)>

# %%
Sic = np.array([np.full(17,0.) for i in range(maxrun)])
for i in range(maxrun):
    with open('Siev_'+repr(i)+'.pkl','rb') as f:
         Sic[i][:] = pickle.load(f)['ST_conf']
Sict = Sic.T
df_conf = pd.DataFrame(Sic, columns =['Chl','oi','fwr','sh','p_lcrit',
              'VcmaxrefChl1', 'VcmaxrefChl2',
             'a1','a3', 'alpha','theta',
             'gamma0', 'gamma1', 'gamma2','g0',
             'kr','kx']) 

dfmean = pd.DataFrame(data=df_mean.mean(),columns=["mean"])
dfmean["maxst"] = (df_mean + df_conf).max()
dfmean["minst"] = (df_mean - df_conf).min()
dfmean['variables']=dfmean.index
dfmeanEv = dfmean

# %%
(
    ggplot(dfmeanEv)  # What data to use
    + aes(x='variables', y= "mean" )  # What variable to use
    + geom_bar(stat = "identity")  # Geometric object to use for drawing
    + xlab("parameter")
    + geom_errorbar(aes(ymin="minst", ymax="maxst"), width=.2) 
    + ylab("total Sobol sensitivity")
)
# Out:
# <ggplot: (8781414059427)>

# %%
Sic = np.array([np.full(17,0.) for i in range(maxrun)])
for i in range(maxrun):
    with open('Sij_'+repr(i)+'.pkl','rb') as f:
         Sic[i][:] = pickle.load(f)['ST_conf']
Sict = Sic.T
df_conf = pd.DataFrame(Sic, columns =['Chl','oi','fwr','sh','p_lcrit',
              'VcmaxrefChl1', 'VcmaxrefChl2',
             'a1','a3', 'alpha','theta',
             'gamma0', 'gamma1', 'gamma2','g0',
             'kr','kx']) 

dfmean = pd.DataFrame(data=df_mean.mean(),columns=["mean"])
dfmean["maxst"] = (df_mean + df_conf).max()
dfmean["minst"] = (df_mean - df_conf).min()
dfmean['variables']=dfmean.index
dfmeanVc = dfmean

# %%
(
    ggplot(dfmeanVc)  # What data to use
    + aes(x='variables', y= "mean" )  # What variable to use
    + geom_bar(stat = "identity")  # Geometric object to use for drawing
    + xlab("parameter")
    #+ geom_errorbar(aes(ymin="minst", ymax="maxst"), width=.2) 
    + ylab("total Sobol sensitivity")
)
# Out:
# <ggplot: (8781414072823)>
