# %%
import sys; 
CPBdir = "../../../../cpb3101/CPlantBox"
sys.path.append(CPBdir+"/src");
sys.path.append(CPBdir);
sys.path.append("../../..");sys.path.append(".."); 
sys.path.append(CPBdir+"/src/python_modules");
sys.path.append("../build-cmake/cpp/python_binding/") # dumux python binding
sys.path.append("../../build-cmake/cpp/python_binding/")
sys.path.append("../modules/") # python wrappers 
from helpuqrMasterCopy1 import *
import numpy as np


def weather(simDuration, hp,condition):
    vgSoil = [0.059, 0.45, 0.00644, 1.503, 1]
    loam = [0.08, 0.43, 0.04, 1.6, 50]
    Qnigh = 0; Qday = 960e-6 #458*2.1
    if (condition == "wet"):
        Tnigh = 15.8; Tday = 22
        #Tnigh = 13; Tday = 20.7
        #specificHumidity = 0.0097
        RHday = 0.60; RHnigh = 0.88
        Pair = 1010.00 #hPa
        thetaInit = 40/100#15.59/100#
        cs = 350e-6
    elif condition == "dry":
        Tnigh = 20.7; Tday = 30.27
        #Tnigh = 15.34; Tday = 23.31
        #specificHumidity = 0.0097# 0.0111
        RHday = 0.3; RHnigh = 0.78
        Pair = 1070.00 #hPa
        thetaInit = 28/100#10.47/100#   
        cs = 350e-6
    else:
        print("condition",condition)
        raise Exception("condition not recognised")
    coefhours = sinusoidal(simDuration)
    RH_ = RHnigh + (RHday - RHnigh) * coefhours
    TairC_ = Tnigh + (Tday - Tnigh) * coefhours
    Q_ = Qnigh + (Qday - Qnigh) * coefhours
     #co2 paartial pressure at leaf surface (mol mol-1)
    #390, 1231
    #RH = 0.5 # relative humidity
    es =  6.112 * np.exp((17.67 * TairC_)/(TairC_ + 243.5))
    ea = es*RH_#qair2ea(specificHumidity,  Pair)
    assert ea < es
    #RH = ea/es
    assert ((RH_ > 0) and(RH_ < 1))
    bl_thickness = 1/1000 #m
    diffusivity= 2.5e-5#m2/sfor 25°C
    rbl =bl_thickness/diffusivity #s/m 13
    #cs = 350e-6
    Kcanopymean = 1e-1 # m2/s
    meanCanopyL = (2/3) * hp /2
    rcanopy = meanCanopyL/Kcanopymean
    windSpeed = 2 #m/s
    zmzh = 2 #m
    karman = 0.41 #[-]

    rair = 1
    if hp > 0:
        rair = np.log((zmzh - (2/3)*hp)/(0.123*hp)) * np.log((zmzh - (2/3)*hp)/(0.1*hp)) / (karman*karman*windSpeed)
        #print()
        #raise Exception


    pmean = theta2H(vgSoil, thetaInit)

    weatherVar = {'TairC' : TairC_,'TairK' : TairC_ + 273.15,'Pair':Pair,"es":es,
                    'Qlight': Q_,'rbl':rbl,'rcanopy':rcanopy,'rair':rair,"ea":ea,
                    'cs':cs, 'RH':RH_, 'p_mean':pmean, 'vg':loam}
    #print("Env variables at", round(simDuration//1),"d",round((simDuration%1)*24),"hrs :\n", weatherVar)
    return weatherVar
def resistance2conductance(resistance,r,weatherX):
    resistance = resistance* (1/100) #[s/m] * [m/cm] = [s/cm]
    resistance = resistance * r.R_ph * weatherX["TairK"] / r.Patm # [s/cm] * [K] * [hPa cm3 K−1 mmol−1] * [hPa] = [s] * [cm2 mmol−1]
    resistance = resistance * (1000) * (1/10000)# [s cm2 mmol−1] * [mmol/mol] * [m2/cm2] = [s m2 mol−1]
    return 1/resistance

def initPlant(simDuration, condition):
    weatherInit = weather(0,0, condition)
    #simDuration = 25 # [day] init simtime
    #spellDuration = 5
    simMax = 26#simStartSim+ spellDuration
    depth = 40
    dt = 1/24 #10min
    verbose = True

    # plant system 
    pl = pb.MappedPlant(seednum = 2) #pb.MappedRootSystem() #pb.MappedPlant()
    #pl2 = pb.MappedPlant(seednum = 2) #pb.MappedRootSystem() #pb.MappedPlant()
    path = CPBdir+"/modelparameter/plant/"
    name = "Triticum_aestivum_test_2021"#"Triticum_aestivum_adapted_2021"#

    pl.readParameters(path + name + ".xml")
    #pl2.readParameters(path + name + ".xml")



    #raise Exception
    sdf = pb.SDF_PlantBox(np.Inf, np.Inf, depth )

    pl.setGeometry(sdf) # creates soil space to stop roots from growing out of the soil
    #pl2.setGeometry(sdf) # creates soil space to stop roots from growing out of the soil


    pl.initialize(verbose = True)#, stochastic = False)
    pl.simulate(simDuration, False)#, "outputpm15.txt")

    #raise Exception
    """ Coupling to soil """



    min_b = [-3./2, -12./2, -41.]#distance between wheat plants
    max_b = [3./2, 12./2, 0.]
    rez = 0.5
    cell_number = [int(6*rez), int(24*rez), int(40*rez)]#1cm3? 
    layers = depth; soilvolume = (depth / layers) * 3 * 12
    k_soil = []
    initial = weatherInit["p_mean"]#mean matric potential [cm] pressure head

    p_mean = initial
    p_bot = p_mean + depth/2
    p_top = initial - depth/2
    sx = np.linspace(p_top, p_bot, depth)
    picker = lambda x,y,z : max(int(np.floor(-z)),-1) 
    sx_static_bu = sx    
    pl.setSoilGrid(picker)  # maps segment



    """ Parameters phloem and photosynthesis """
    r = PhloemFluxPython(pl,psiXylInit = min(sx),ciInit = weatherInit["cs"]*0.5) #XylemFluxPython(pl)#
    #r2 = PhloemFluxPython(#pl2,psiXylInit = min(sx),ciInit = weatherInit["cs"]*0.5) #XylemFluxPython(pl)#

    r = setKrKx_phloem(r)

    r.oldciEq = True

    r.Rd_ref = 0 #to avoid error (C < 0 in meso, mention this in paper)
    r.g0 = 8e-3
    r.VcmaxrefChl1 =1.28
    r.VcmaxrefChl2 = 8.33
    r.a1 = 0.6/0.4#0.7/0.3#0.6/0.4 #ci/(cs - ci) for ci = 0.6*cs
    r.a3 = 1.5
    r.alpha = 0.4#0.2#/2
    r.theta = 0.6#0.9#/2
    r.k_meso = 1e-3#1e-4
    r.setKrm2([[2e-5]])
    r.setKrm1([[10e-2]])#([[2.5e-2]])
    r.setRhoSucrose([[0.51],[0.65],[0.56]])#0.51
    #([[14.4,9.0,0,14.4],[5.,5.],[15.]])
    rootFact = 2
    r.setRmax_st([[2.4*rootFact,1.5*rootFact,0.6*rootFact,2.4*rootFact],[2.,2.],[8.]])#6.0#*6 for roots, *1 for stem, *24/14*1.5 for leaves
    #r.setRmax_st([[12,9.0,6.0,12],[5.,5.],[15.]])
    r.KMrm = 0.1#VERY IMPORTANT TO KEEP IT HIGH
    #r.exud_k = np.array([2.4e-4])#*10#*(1e-1)
    #r.k_gr = 1#0
    r.sameVolume_meso_st = False
    r.sameVolume_meso_seg = True
    r.withInitVal =True
    r.initValST = 0.#0.6#0.0
    r.initValMeso = 0.#0.9#0.0
    r.beta_loading = 0.6
    r.Vmaxloading = 0.05 #mmol/d, needed mean loading rate:  0.3788921068507634
    r.Mloading = 0.2
    r.Gr_Y = 0.8
    r.CSTimin = 0.4
    r.surfMeso=0.0025
    r.leafGrowthZone = 2 # cm
    r.StemGrowthPerPhytomer = True # 
    r.psi_osmo_proto = -10000*1.0197 #schopfer2006
    r.fwr = 0

    r.cs = weatherInit["cs"]

    #r.r_forPhloem(24/14*1.5, 4)
    #r.r_forPhloem(24/14, 3)
    #r.r_forPhloem(6, 2) #because roots will have high C_ST less often
    r.expression = 6
    r.update_viscosity = True
    r.solver = 1
    r.atol = 1e-10
    r.rtol = 1e-6
    #r.doNewtonRaphson = False;r.doOldEq = False
    SPAD= 41.0
    chl_ = (0.114 *(SPAD**2)+ 7.39 *SPAD+ 10.6)/10
    r.Chl = np.array( [chl_]) 
    r.Csoil = 1e-4
    
    hp = max([tempnode[2] for tempnode in r.get_nodes()]) /100 

    weatherX = weather(simDuration, hp,condition)
    r.Patm = weatherX["Pair"]
    ##resistances
    r.g_bl = resistance2conductance(weatherX["rbl"],r,weatherX) / r.a2_bl
    r.g_canopy = resistance2conductance(weatherX["rcanopy"],r,weatherX) / r.a2_canopy
    r.g_air = resistance2conductance(weatherX["rair"],r,weatherX) / r.a2_air
    r.sh = 4e-4
    r.fwr = 0#0.001
    r.shmesophyll = 4e-4
    r.fwrmesophyll = 0#0.001
    r.p_lcritmesophyll=-100000
    #r.gm = 0.05
    r.g0 = 8e-6
    r.alternativeAn = False
    r.limMaxErr = 1/100;

    r.Qlight = weatherX["Qlight"] #; TairC = weatherX["TairC"] ; text = "night"


    r = setKrKx_xylem(weatherX["TairC"], weatherX["RH"],r)
    kr_l  = 3.83e-7
    #r.setKr_meso([kr_l]) 
    r.es = weatherX["es"]
    return r, weatherX, sx
simDuration = 10
rinit=initPlant(simDuration, condition="wet")
r = rinit[0]
weatherX = rinit[1] 
sx =rinit[2]#np.linspace(-100, -20000, 100)
p_errors =[]
r.usePg4Fw = False
dt=1/24
directoryN="/testPhoto2/"
while simDuration <= 11:
    hp = max([tempnode[2] for tempnode in r.get_nodes()]) /100 #maxnode canopy [m]
    #print([tempnode[2] for tempnode in r.get_nodes()], hp)

    weatherX = weather(simDuration, hp,"wet")
    r.Patm = weatherX["Pair"]
    ##resistances
    r.g_bl = resistance2conductance(weatherX["rbl"],r,weatherX) / r.a2_bl
    r.g_canopy = resistance2conductance(weatherX["rcanopy"],r,weatherX) / r.a2_canopy
    r.g_air = resistance2conductance(weatherX["rair"],r,weatherX) / r.a2_air

    r.Qlight = weatherX["Qlight"] #; TairC = weatherX["TairC"] ; text = "night"


    r = setKrKx_xylem(weatherX["TairC"], weatherX["RH"],r)
    
    #kr_l  = 3.83e-7
    #r.setKr_meso([kr_l]) 
    r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                    verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
    startphloem= simDuration
    endphloem = startphloem + dt
    stepphloem = 1
    filename = "results"+ directoryN +"inPM_"+str(0)+".txt"
    r.startPM(startphloem, endphloem, stepphloem, ( weatherX["TairC"]  +273.15) , False, filename)
    r.plant.simulate(dt, False)
    try:
        os.remove(filename)
    except OSError:
        pass   
    simDuration += dt
# Out:
# MappedPlant::initialize
# Seed::initialize: Plant
# Seed::initialize: Basal root type #4 was not defined, using tap root parameters instead
# Tiller stem type #4 was not defined, using main stem parameters instead, Exchange zone in roots: kr_st > 0 until 0.8cm from root tip 1 1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr_st is constant per subtype of organ type, for root, subtype 1 = 0.05 1 day-1
# Kx_st is constant per subtype of organ type, for root, subtype 1 = 1.32591e-13 cm3 day-1
# Across_st is constant per subtype of organ type, for root, subtype 1 = 9.62113e-06 cm2
# krm2 is constant 2e-05 -
# krm1 is constant 0.1 -
# rhoSucrose is constant per organ type, organ type 2 (root) = 0.51 mmol cm-3
# Rmax_st is constant per subtype of organ type, for root, subtype 1 = 3 cm day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Output times :
#  10 10.0417
# starting integration on time segment #1 = [10, 10.0417] 2 2
# at t = 10 : Y0.size() = 1269
# at 23:45:16 :  starting step n#1 (tf = 10.0417)
# at t = 10.0417 : Y0.size() = 1269
#
# Final Statistics:
# nst (num steps) = 780    nfe  (num call to f)= 1478   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1475   ncfn (non linsolver conv fail)= 330    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0692154 cm3 day-1
# Output times :
#  10.0417 10.0833
# starting integration on time segment #1 = [10.0417, 10.0833] 2 2
# at t = 10.0417 : Y0.size() = 1269
# at 23:45:16 :  starting step n#1 (tf = 10.0833)
# at t = 10.0833 : Y0.size() = 1269
#
# Final Statistics:
# nst (num steps) = 1453   nfe  (num call to f)= 2826   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2823   ncfn (non linsolver conv fail)= 683    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0705129 cm3 day-1
# Output times :
#  10.0833 10.125
# starting integration on time segment #1 = [10.0833, 10.125] 2 2
# at t = 10.0833 : Y0.size() = 1269
# at 23:45:16 :  starting step n#1 (tf = 10.125)
# at t = 10.125 : Y0.size() = 1269
#
# Final Statistics:
# nst (num steps) = 1239   nfe  (num call to f)= 2376   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2373   ncfn (non linsolver conv fail)= 559    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0716323 cm3 day-1
# Output times :
#  10.125 10.1667
# starting integration on time segment #1 = [10.125, 10.1667] 2 2
# at t = 10.125 : Y0.size() = 1269
# at 23:45:16 :  starting step n#1 (tf = 10.1667)
# at t = 10.1667 : Y0.size() = 1269
#
# Final Statistics:
# nst (num steps) = 1223   nfe  (num call to f)= 2272   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2269   ncfn (non linsolver conv fail)= 514    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0724945 cm3 day-1
# Output times :
#  10.1667 10.2083
# starting integration on time segment #1 = [10.1667, 10.2083] 2 2
# at t = 10.1667 : Y0.size() = 1269
# at 23:45:16 :  starting step n#1 (tf = 10.2083)
# at t = 10.2083 : Y0.size() = 1269
#
# Final Statistics:
# nst (num steps) = 1049   nfe  (num call to f)= 2006   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2003   ncfn (non linsolver conv fail)= 469    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0730379 cm3 day-1
# Output times :
#  10.2083 10.25
# starting integration on time segment #1 = [10.2083, 10.25] 2 2
# at t = 10.2083 : Y0.size() = 1269
# at 23:45:16 :  starting step n#1 (tf = 10.25)
# at t = 10.25 : Y0.size() = 1269
#
# Final Statistics:
# nst (num steps) = 911    nfe  (num call to f)= 1696   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1693   ncfn (non linsolver conv fail)= 384    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0732234 cm3 day-1
# Output times :
#  10.25 10.2917
# starting integration on time segment #1 = [10.25, 10.2917] 2 2
# at t = 10.25 : Y0.size() = 1296
# at 23:45:16 :  starting step n#1 (tf = 10.2917)
# at t = 10.2917 : Y0.size() = 1296
#
# Final Statistics:
# nst (num steps) = 755    nfe  (num call to f)= 1396   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1393   ncfn (non linsolver conv fail)= 305    netf (num err test fail) = 2      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0730379 cm3 day-1
# Output times :
#  10.2917 10.3333
# starting integration on time segment #1 = [10.2917, 10.3333] 2 2
# at t = 10.2917 : Y0.size() = 1296
# at 23:45:16 :  starting step n#1 (tf = 10.3333)
# at t = 10.3333 : Y0.size() = 1296
#
# Final Statistics:
# nst (num steps) = 1091   nfe  (num call to f)= 1963   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1960   ncfn (non linsolver conv fail)= 427    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0724945 cm3 day-1
# Output times :
#  10.3333 10.375
# starting integration on time segment #1 = [10.3333, 10.375] 2 2
# at t = 10.3333 : Y0.size() = 1314
# at 23:45:16 :  starting step n#1 (tf = 10.375)
# at t = 10.375 : Y0.size() = 1314
#
# Final Statistics:
# nst (num steps) = 891    nfe  (num call to f)= 1604   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1601   ncfn (non linsolver conv fail)= 342    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0716323 cm3 day-1
# Output times :
#  10.375 10.4167
# starting integration on time segment #1 = [10.375, 10.4167] 2 2
# at t = 10.375 : Y0.size() = 1323
# at 23:45:16 :  starting step n#1 (tf = 10.4167)
# at t = 10.4167 : Y0.size() = 1323
#
# Final Statistics:
# nst (num steps) = 549    nfe  (num call to f)= 952    nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 949    ncfn (non linsolver conv fail)= 186    netf (num err test fail) = 2      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0705129 cm3 day-1
# Output times :
#  10.4167 10.4583
# starting integration on time segment #1 = [10.4167, 10.4583] 2 2
# at t = 10.4167 : Y0.size() = 1332
# at 23:45:16 :  starting step n#1 (tf = 10.4583)
# at t = 10.4583 : Y0.size() = 1332
#
# Final Statistics:
# nst (num steps) = 975    nfe  (num call to f)= 1765   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1762   ncfn (non linsolver conv fail)= 382    netf (num err test fail) = 2      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0692154 cm3 day-1
# Output times :
#  10.4583 10.5
# starting integration on time segment #1 = [10.4583, 10.5] 2 2
# at t = 10.4583 : Y0.size() = 1341
# at 23:45:16 :  starting step n#1 (tf = 10.5)
# at t = 10.5 : Y0.size() = 1341
#
# Final Statistics:
# nst (num steps) = 881    nfe  (num call to f)= 1673   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1670   ncfn (non linsolver conv fail)= 382    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Output times :
#  10.5 10.5417
# starting integration on time segment #1 = [10.5, 10.5417] 2 2
# at t = 10.5 : Y0.size() = 1350
# at 23:45:16 :  starting step n#1 (tf = 10.5417)
# at t = 10.5417 : Y0.size() = 1350
#
# Final Statistics:
# nst (num steps) = 854    nfe  (num call to f)= 1561   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1558   ncfn (non linsolver conv fail)= 341    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0664536 cm3 day-1
# Output times :
#  10.5417 10.5833
# starting integration on time segment #1 = [10.5417, 10.5833] 2 2
# at t = 10.5417 : Y0.size() = 1377
# at 23:45:16 :  starting step n#1 (tf = 10.5833)
# at t = 10.5833 : Y0.size() = 1377
#
# Final Statistics:
# nst (num steps) = 922    nfe  (num call to f)= 1775   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1772   ncfn (non linsolver conv fail)= 414    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0651778 cm3 day-1
# Output times :
#  10.5833 10.625
# starting integration on time segment #1 = [10.5833, 10.625] 2 2
# at t = 10.5833 : Y0.size() = 1386
# at 23:45:16 :  starting step n#1 (tf = 10.625)
# at t = 10.625 : Y0.size() = 1386
#
# Final Statistics:
# nst (num steps) = 1003   nfe  (num call to f)= 1916   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1913   ncfn (non linsolver conv fail)= 443    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0640881 cm3 day-1
# Output times :
#  10.625 10.6667
# starting integration on time segment #1 = [10.625, 10.6667] 2 2
# at t = 10.625 : Y0.size() = 1422
# at 23:45:16 :  starting step n#1 (tf = 10.6667)
# at t = 10.6667 : Y0.size() = 1422
#
# Final Statistics:
# nst (num steps) = 1149   nfe  (num call to f)= 2049   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2047   ncfn (non linsolver conv fail)= 439    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0632556 cm3 day-1
# Output times :
#  10.6667 10.7083
# starting integration on time segment #1 = [10.6667, 10.7083] 2 2
# at t = 10.6667 : Y0.size() = 1431
# at 23:45:16 :  starting step n#1 (tf = 10.7083)
# at t = 10.7083 : Y0.size() = 1431
#
# Final Statistics:
# nst (num steps) = 1250   nfe  (num call to f)= 2334   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2331   ncfn (non linsolver conv fail)= 530    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.062734 cm3 day-1
# Output times :
#  10.7083 10.75
# starting integration on time segment #1 = [10.7083, 10.75] 2 2
# at t = 10.7083 : Y0.size() = 1467
# at 23:45:16 :  starting step n#1 (tf = 10.75)
# at t = 10.75 : Y0.size() = 1467
#
# Final Statistics:
# nst (num steps) = 949    nfe  (num call to f)= 1728   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1725   ncfn (non linsolver conv fail)= 378    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0625564 cm3 day-1
# Output times :
#  10.75 10.7917
# starting integration on time segment #1 = [10.75, 10.7917] 2 2
# at t = 10.75 : Y0.size() = 1485
# at 23:45:16 :  starting step n#1 (tf = 10.7917)
# at t = 10.7917 : Y0.size() = 1485
#
# Final Statistics:
# nst (num steps) = 803    nfe  (num call to f)= 1442   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1439   ncfn (non linsolver conv fail)= 308    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.062734 cm3 day-1
# Output times :
#  10.7917 10.8333
# starting integration on time segment #1 = [10.7917, 10.8333] 2 2
# at t = 10.7917 : Y0.size() = 1530
# at 23:45:16 :  starting step n#1 (tf = 10.8333)
# at t = 10.8333 : Y0.size() = 1530
#
# Final Statistics:
# nst (num steps) = 1036   nfe  (num call to f)= 1859   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1856   ncfn (non linsolver conv fail)= 399    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0632556 cm3 day-1
# Output times :
#  10.8333 10.875
# starting integration on time segment #1 = [10.8333, 10.875] 2 2
# at t = 10.8333 : Y0.size() = 1530
# at 23:45:16 :  starting step n#1 (tf = 10.875)
# at t = 10.875 : Y0.size() = 1530
#
# Final Statistics:
# nst (num steps) = 831    nfe  (num call to f)= 1576   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1573   ncfn (non linsolver conv fail)= 367    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0640881 cm3 day-1
# Output times :
#  10.875 10.9167
# starting integration on time segment #1 = [10.875, 10.9167] 2 2
# at t = 10.875 : Y0.size() = 1557
# at 23:45:16 :  starting step n#1 (tf = 10.9167)
# at t = 10.9167 : Y0.size() = 1557
#
# Final Statistics:
# nst (num steps) = 1010   nfe  (num call to f)= 1980   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 1977   ncfn (non linsolver conv fail)= 472    netf (num err test fail) = 0      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0651778 cm3 day-1
# Output times :
#  10.9167 10.9583
# starting integration on time segment #1 = [10.9167, 10.9583] 2 2
# at t = 10.9167 : Y0.size() = 1584
# at 23:45:16 :  starting step n#1 (tf = 10.9583)
# at t = 10.9583 : Y0.size() = 1584
#
# Final Statistics:
# nst (num steps) = 1272   nfe  (num call to f)= 2410   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2407   ncfn (non linsolver conv fail)= 554    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0664536 cm3 day-1
# Output times :
#  10.9583 11
# starting integration on time segment #1 = [10.9583, 11] 2 2
# at t = 10.9583 : Y0.size() = 1620
# at 23:45:16 :  starting step n#1 (tf = 11)
# at t = 11 : Y0.size() = 1620
#
# Final Statistics:
# nst (num steps) = 1099   nfe  (num call to f)= 2061   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2059   ncfn (non linsolver conv fail)= 470    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0678305 cm3 day-1
# Output times :
#  11 11.0417
# starting integration on time segment #1 = [11, 11.0417] 2 2
# at t = 11 : Y0.size() = 1647
# at 23:45:16 :  starting step n#1 (tf = 11.0417)
# at t = 11.0417 : Y0.size() = 1647
#
# Final Statistics:
# nst (num steps) = 1139   nfe  (num call to f)= 2007   nsetups (call to lin solver setup func)= 0
#
# nni (iter of nonlinear solver) = 2005   ncfn (non linsolver conv fail)= 421    netf (num err test fail) = 1      nge (call to root function) = 0
#
#
# at 23:45:16 :  exiting solver
# MEMORY LIBERATIONS
# fortran to python vector
# computeOrgGrowth

# %%
rootLength = np.array([mr.getLength(False) for mr in r.plant.getOrgans(2, False)])
st4leng = np.array([mr.getParameter("subType") for mr in r.plant.getOrgans(2, False)])
root1Length = sum([mr.getLength(False)*((mr.getParameter("subType")==1)or(mr.getParameter("subType")==4)) for mr in r.plant.getOrgans(2, False)])
root2Length = sum([mr.getLength(False)*((mr.getParameter("subType")==2))  for mr in r.plant.getOrgans(2, False)])
root3Length = sum([mr.getLength(False)*((mr.getParameter("subType")==3))  for mr in r.plant.getOrgans(2, False)])
leafLength = sum([mr.getLength(False) for mr in r.plant.getOrgans(4, False)])
print("root length {:5.2e}\tlef length {:5.2e}".format(sum(rootLength),leafLength))
print("length root1 {:5.2e}\troot2 {:5.2e}\troot3 {:5.2e}".format(root1Length,root2Length,root3Length))

#root length 1.63e+02	lef length 4.40e+01
#length root1 6.29e+01	root2 9.96e+01	root3 0.00e+00
# Out:
# root length 1.70e+02	lef length 4.48e+01
# length root1 6.39e+01	root2 1.07e+02	root3 0.00e+00

# %%
#print(r.k_leaf,r.k_stomatas,r.gco2,r.psi_air,r.pg,r.fwmesophyll)
print(r.fw,r.fw_old)
# Out:
# [0.0, 0.0, 0.0, 0.0, 0.9208141964413485, 0.9206710612842881, 0.9205356878574089, 0.9204081452307484, 0.9202885191440102, 0.9201768957340938, 0.9200733622772287, 0.9199779912663318, 0.9198908502369552, 0.0, 0.0, 0.0, 0.0, 0.9210122432686917, 0.9209131467937334, 0.9208216618368987, 0.0, 0.9198283207169138, 0.9207520031777163] [0.0, 0.0, 0.0, 0.0, 0.9228583036385674, 0.9227182132268141, 0.9225856518564074, 0.9224606871844278, 0.9223434033499409, 0.9222338849244237, 0.9221322176442932, 0.9220384727064533, 0.9219527164603617, 0.0, 0.0, 0.0, 0.0, 0.923050022129476, 0.9229525602080719, 0.9228624881842691, 0.0, 0.9218911150991462, 0.9227938457322]

# %%
def sinusoidal(t):
    return 1#(np.sin(np.pi*t*2)+1)/2 
def weather(simDuration, hp,condition):
    vgSoil = [0.059, 0.45, 0.00644, 1.503, 1]
    loam = [0.08, 0.43, 0.04, 1.6, 50]
    Qnigh = 0; Qday = 960e-6 #458*2.1
    if (condition == "wet"):
        Tnigh = 15.8; Tday = 22
        #Tnigh = 13; Tday = 20.7
        #specificHumidity = 0.0097
        RHday = 0.60; RHnigh = 0.88
        Pair = 1010.00 #hPa
        thetaInit = 40/100#15.59/100#
        cs = 350e-6
    elif condition == "dry":
        Tnigh = 20.7; Tday = 30.27
        #Tnigh = 15.34; Tday = 23.31
        #specificHumidity = 0.0097# 0.0111
        RHday = 0.30; RHnigh = 0.78
        Pair = 1070.00 #hPa
        thetaInit = 28/100#10.47/100#   
        cs = 350e-6
    else:
        print("condition",condition)
        raise Exception("condition not recognised")
    coefhours = sinusoidal(simDuration)
    RH_ = RHnigh + (RHday - RHnigh) * coefhours
    TairC_ = Tnigh + (Tday - Tnigh) * coefhours
    Q_ = Qnigh + (Qday - Qnigh) * coefhours
     #co2 paartial pressure at leaf surface (mol mol-1)
    #390, 1231
    #RH = 0.5 # relative humidity
    es =  6.112 * np.exp((17.67 * TairC_)/(TairC_ + 243.5))
    ea = es*RH_#qair2ea(specificHumidity,  Pair)
    assert ea < es
    #RH = ea/es
    assert ((RH_ > 0) and(RH_ < 1))
    bl_thickness = 1/1000 #m
    diffusivity= 2.5e-5#m2/sfor 25°C
    rbl =bl_thickness/diffusivity #s/m 13
    #cs = 350e-6
    Kcanopymean = 1e-1 # m2/s
    meanCanopyL = (2/3) * hp /2
    rcanopy = meanCanopyL/Kcanopymean
    windSpeed = 2 #m/s
    zmzh = 2 #m
    karman = 0.41 #[-]

    rair = 1
    if hp > 0:
        rair = np.log((zmzh - (2/3)*hp)/(0.123*hp)) * np.log((zmzh - (2/3)*hp)/(0.1*hp)) / (karman*karman*windSpeed)
        #print()
        #raise Exception


    pmean = theta2H(vgSoil, thetaInit)

    weatherVar = {'TairC' : TairC_,'TairK' : TairC_ + 273.15,'Pair':Pair,"es":es,
                    'Qlight': Q_,'rbl':rbl,'rcanopy':rcanopy,'rair':rair,"ea":ea,
                    'cs':cs, 'RH':RH_, 'p_mean':pmean, 'vg':loam}
    #print("Env variables at", round(simDuration//1),"d",round((simDuration%1)*24),"hrs :\n", weatherVar)
    return weatherVar

# %%
#test effect of watpot
#simDuration = 12.166666666666636#12.208333333333302
#print(weather(simDuration, hp,"dry"))
simDuration = 12.208333333333302
weatherX = weather(simDuration, hp,"dry")
#print(weatherX)
#raise Exception
#print(weatherX)
#raise Exception

testPsoil = np.linspace(-15000, -500,500)#np.array([-4742.48496993988,-4713.426853707415])#
#np.linspace(-15000, -500,500)#
#np.array([-9854.454454454455,-9853.353353353354])#np.linspace(-10100, -9000,1000)

EvRate = []
Ev = []
An = []
Vc = []
Vj = []
Anrate = []
Vcrate = []
Vjrate = []
gco2 = []
ci = []
fw = []
fwold = []
fwVold = []
pg = []
pl = []
k_stomatas = []
loop=[]
r.usePg4Fw = True
psiXylBU=np.full(len(r.psiXyl),-1000)
pgBU =np.full(len(r.pg),-1000)
r.Theta_ag = 1#0.7
#print(r.useVj)
r.alternativeAn =False
r.p_lcrit=-10000
#r.p_lcritmesophyll=-10000
#
print(r.doWiggle)
#r.doWiggle=True
r.limMaxErr = 1/100
r.gm=0.02
r.g0=0
r.fwr=0
r.a1=6
r.minLoop=100
r.VcmaxrefChl1 =1.28*2#/4
r.VcmaxrefChl2 = 8.33*2#/4
directoryN="/testPhoto2/success/"

testPsoiLight = np.linspace(0,1,500)
#for i, lightI in enumerate(testPsoiLight):#while not stop:
for i, p_mean in enumerate(testPsoil):#while not stop:
    depth=60
    print(i, p_mean)
    #print(i, lightI)
    #p_mean = -600
    p_bot = p_mean + depth/2
    p_top = p_mean - depth/2
    sx = np.linspace(p_top, p_bot, depth)
    
    hp = max([tempnode[2] for tempnode in r.get_nodes()]) /100 #maxnode canopy [m]
    #print([tempnode[2] for tempnode in r.get_nodes()], hp)

    weatherX = weather(simDuration, hp,"dry")
    r.Patm = weatherX["Pair"]
    ##resistances
    r.g_bl = resistance2conductance(weatherX["rbl"],r,weatherX) / r.a2_bl
    r.g_canopy = resistance2conductance(weatherX["rcanopy"],r,weatherX) / r.a2_canopy
    r.g_air = resistance2conductance(weatherX["rair"],r,weatherX) / r.a2_air

    r.Qlight = weatherX["Qlight"]#*lightI#; TairC = weatherX["TairC"] ; text = "night"


    r = setKrKx_xylem(weatherX["TairC"], weatherX["RH"],r)
    
    
    success = False
    
    #r.psiXyl = np.full(len(r.psiXyl),-1000)#psiXylBU#
    #r.pg = np.full(len(r.pg),-1000)#pgBU #
    r.loop=0
    r.maxLoop=1000
    r.followTrace = False
    r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                        verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
    try:
        r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                        verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
        success = True
        psiXylBU = r.psiXyl
        pbBU = r.pg
        directoryN="/testPhoto2/failure/"
    except:
        print("param space search")
        testPplant = np.linspace(1,0.01,100)
        success=False
        for i, Pinit in enumerate(testPplant):

            r.followTrace = False
            r.psiXyl = np.array(psiXylBU)*Pinit#np.full(len(r.psiXyl),Pinit)#
            r.pg = np.array(pbBU)*Pinit#np.full(len(r.pg),Pinit)#pgBU 
            #print(i, r.psiXyl,r.pg)
            try:
                r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],
                                verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
                success = True
                psiXylBU = r.psiXyl
                pbBU = r.pg
            except:
                print("r.loop>r.maxLoop",r.loop,r.maxLoop)
                #assert(r.loop>r.maxLoop)
                success = False
            if success:
                print("r.loop>r.maxLoop",r.loop,r.maxLoop)
                print("SUCCESS param space search")
                break
        if not success:
            print("FAIL param space search")
            #r.maxLoop=100
            #r.followTrace = False
            #r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],
             #               verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)

            raise Exception
            print("photosynthesis::solve: did not reach convergence")
            success = False
            
    print("numLoop ",r.loop)
    leaf_nodes = r.get_nodes_index(4)
    if True:#success
        loop.append(r.loop)
        Ev.append(sum(r.Ev))
        An.append(sum(r.An)*1e6)
        Vc.append(sum(r.Vc)*1e6)
        Vj.append(sum(r.Vj)*1e6)
        Anrate.append(np.mean(np.array(r.An)[np.array(r.ci) >0])*1e6)
        Vcrate.append(np.mean(np.array(r.Vc)[np.array(r.ci) >0])*1e6)
        Vjrate.append(np.mean(np.array(r.Vj)[np.array(r.ci) >0])*1e6)
        
        EvRate.append(np.mean(np.array(r.Jw)[np.array(r.ci) >0]))
        gco2.append(np.mean(np.array(r.gco2)[np.array(r.ci) >0]))
        ci.append(np.mean(np.array(r.ci)[np.array(r.ci) >0]))
        fw.append(np.mean(np.array(r.fw)[np.array(r.ci) >0]))
        fwold.append(np.mean(np.array(r.fw_old)[np.array(r.ci) >0]))
        fwVold.append(np.mean(np.array(r.fw_very_old)[np.array(r.ci) >0]))
        pg.append(np.mean(np.array(r.pg)[np.array(r.ci) >0]))
        #pl.append(np.mean(np.array(r.psiXyl)[leaf_nodes][np.array(r.ci) >0]))
        k_stomatas.append(np.mean(np.array(r.k_stomatas)[np.array(r.ci) >0]))
    else:
        Ev.append(np.nan)
        An.append(np.nan)
        Vc.append(np.nan)
        Vj.append(np.nan)
        gco2.append(np.nan)
        ci.append(np.nan)
        fw.append(np.mean(np.array(r.fw)[np.array(r.ci) >0]))
        fwold.append(np.mean(np.array(r.fw_old)[np.array(r.ci) >0]))
        fwVold.append(np.mean(np.array(r.fw_very_old)[np.array(r.ci) >0]))
        pg.append(np.nan)
        #pl.append(np.nan)
        k_stomatas.append(np.nan)

print("finised test")
# Out:
# False
# 0 -15000.0
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 1 -14970.941883767535
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 2 -14941.88376753507
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 3 -14912.825651302604
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 4 -14883.767535070141
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 5 -14854.709418837676
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 6 -14825.65130260521
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 7 -14796.593186372746
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 8 -14767.53507014028
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 9 -14738.476953907815
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 10 -14709.41883767535
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 11 -14680.360721442887
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 12 -14651.302605210421
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 13 -14622.244488977956
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 14 -14593.186372745491
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 15 -14564.128256513026
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 16 -14535.07014028056
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 17 -14506.012024048096
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 18 -14476.95390781563
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 19 -14447.895791583167
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 20 -14418.837675350702
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 21 -14389.779559118237
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 22 -14360.721442885771
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 23 -14331.663326653306
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 24 -14302.605210420841
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 25 -14273.547094188376
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 26 -14244.488977955913
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 27 -14215.430861723447
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 28 -14186.372745490982
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 29 -14157.314629258517
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 30 -14128.256513026052
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 31 -14099.198396793587
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 32 -14070.140280561121
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 33 -14041.082164328658
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 34 -14012.024048096193
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 35 -13982.965931863728
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 36 -13953.907815631263
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 37 -13924.849699398797
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 38 -13895.791583166332
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 39 -13866.733466933867
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 40 -13837.675350701404
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 41 -13808.617234468938
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 42 -13779.559118236473
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 43 -13750.501002004008
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 44 -13721.442885771543
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 45 -13692.384769539078
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 46 -13663.326653306613
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 47 -13634.26853707415
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 48 -13605.210420841684
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 49 -13576.152304609219
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
#
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 168 -10118.236472945893
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 169 -10089.178356713426
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 170 -10060.120240480963
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 171 -10031.062124248496
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 172 -10002.004008016032
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 173 -9972.945891783567
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 174 -9943.887775551102
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 175 -9914.829659318639
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 176 -9885.771543086172
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 177 -9856.713426853708
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 178 -9827.655310621241
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 179 -9798.597194388778
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 180 -9769.539078156313
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 181 -9740.480961923848
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 182 -9711.422845691382
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# ...
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 440 -2214.428857715431
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 441 -2185.370741482966
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 442 -2156.312625250501
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 443 -2127.2545090180356
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 444 -2098.1963927855722
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 445 -2069.138276553107
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 446 -2040.0801603206419
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 447 -2011.0220440881767
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 448 -1981.9639278557115
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 449 -1952.9058116232463
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 450 -1923.8476953907812
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 451 -1894.7895791583178
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 452 -1865.7314629258526
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 453 -1836.6733466933874
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 454 -1807.6152304609222
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 455 -1778.557114228457
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 456 -1749.4989979959919
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 457 -1720.4408817635267
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 458 -1691.3827655310633
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 459 -1662.3246492985982
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 460 -1633.266533066133
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 461 -1604.2084168336678
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 462 -1575.1503006012026
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 463 -1546.0921843687374
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 464 -1517.0340681362723
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 465 -1487.975951903807
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 466 -1458.9178356713437
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 467 -1429.8597194388785
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 468 -1400.8016032064133
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 469 -1371.7434869739482
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 470 -1342.685370741483
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 471 -1313.6272545090178
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 472 -1284.5691382765526
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 473 -1255.5110220440893
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 474 -1226.452905811624
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 475 -1197.394789579159
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 476 -1168.3366733466937
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 477 -1139.2785571142285
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 478 -1110.2204408817634
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 479 -1081.1623246492982
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 480 -1052.1042084168348
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 481 -1023.0460921843696
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 482 -993.9879759519044
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 483 -964.9298597194393
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 484 -935.8717434869741
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 485 -906.8136272545089
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 486 -877.7555110220437
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 487 -848.6973947895804
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 488 -819.6392785571152
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 489 -790.58116232465
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 490 -761.5230460921848
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 491 -732.4649298597196
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 492 -703.4068136272545
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 493 -674.3486973947893
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 494 -645.2905811623259
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 495 -616.2324649298607
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 496 -587.1743486973955
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 497 -558.1162324649304
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 498 -529.0581162324652
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# 499 -500.0
# Kr is constant per subtype of organ type, for root, subtype 0 = 6.49549e-05 1 day-1
# Kx is constant per subtype of organ type, for root, subtype 0 = 0.0880999 cm3 day-1
# Exchange zone in roots: kr > 0 until 0.8cm from root tip
# numLoop  102
# finised test

# %%
#psibu2 = np.array(r.psiXyl)
#weatherX=weather(simDuration, hp,"wet")
r.maxLoop = 1000
#r.minLoop=900
r.gm=0.03
#try
r.followTrace = True
#r.p_lcrit=-10000
#r.a1=6
#r.Rd_ref = 0.32e-6
r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
                        verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
#except:
 #   psibu3 =np.array(r.psiXyl)
print(r.gco2,r.fw)#,r.pg,r.fw,r.Ev)
#print(sum(r.Ev),np.array(r.An)*1e6,np.array(r.An)*1e6/np.array(r.Jw)/1000/( 18/1000 * 24. * 3600 * 1e-4),r.fw,r.pg,np.array(r.ci)/r.cs)
#print(np.array(r.Vc)*1e6,np.array(r.Vj)*1e6)#,r.Vcmax)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 11
#       7 r.followTrace = True
#       8 #r.p_lcrit=-10000
#       9 #r.a1=6
#      10 #r.Rd_ref = 0.32e-6
# ---> 11 r.solve_photosynthesis(sim_time_ = simDuration, sxx_=sx, cells_ = True,ea_ = weatherX["ea"],es_ = weatherX["es"],
#      12                         verbose_ = False, doLog_ = False,TairC_= weatherX["TairC"],outputDir_= "./results"+directoryN)
#      13 #except:
#      14  #   psibu3 =np.array(r.psiXyl)
#      15 print(r.gco2,r.fw)#,r.pg,r.fw,r.Ev)
#
# RuntimeError: photosynthesis::solve: did not reach convergence

# %%
print(np.array(r.ci) -np.array(r.deltagco2),np.array(r.Vcrefmax)*1e6,np.array(r.Jrefmax)*1e6,(r.VcmaxrefChl1*r.Chl[0]+r.VcmaxrefChl2)*1e-6, r.An)
# Out:
# [-4.51651581e-05 -4.51651581e-05 -4.51651581e-05 -4.51651581e-05
#   2.25602188e-04  2.25585535e-04  2.25568784e-04  2.25551948e-04
#   2.25535043e-04  2.25518087e-04  2.25501097e-04  2.25484087e-04
#   2.25467070e-04 -4.51651581e-05 -4.51651581e-05 -4.51651581e-05
#  -4.51651581e-05  2.25594089e-04  2.25575615e-04  2.25557093e-04
#  -4.51651581e-05  2.25542548e-04  2.25454159e-04] [145.997344 145.997344 145.997344 145.997344 145.997344 145.997344
#  145.997344 145.997344 145.997344 145.997344 145.997344 145.997344
#  145.997344 145.997344 145.997344 145.997344 145.997344 145.997344
#  145.997344 145.997344 145.997344 145.997344 145.997344] [218.996016 218.996016 218.996016 218.996016 218.996016 218.996016
#  218.996016 218.996016 218.996016 218.996016 218.996016 218.996016
#  218.996016 218.996016 218.996016 218.996016 218.996016 218.996016
#  218.996016 218.996016 218.996016 218.996016 218.996016] 0.00014599734399999999 [0.0, 0.0, 0.0, 0.0, 2.6000266309586452e-05, 2.5999546104043842e-05, 2.5998821603960106e-05, 2.599809335837634e-05, 2.5997362087351532e-05, 2.5996628521677358e-05, 2.599589341045041e-05, 2.5995157364370515e-05, 2.5994420952852575e-05, 0.0, 0.0, 0.0, 0.0, 2.5999916064266696e-05, 2.59991170555556e-05, 2.599831593394818e-05, 0.0, 2.59976867365047e-05, 2.5993862168609645e-05]

# %%
print(np.array(r.Jw)*1000 *18/1000 * 24. * 3600 * 1e-4)
# Out:
# [ 0.          0.          0.          0.         14.28883074 14.28497439
#  14.28109694 14.27720137 14.27329153 14.26937137 14.2654449  14.26151539
#  14.25758589  0.          0.          0.          0.         14.28695511
#  14.28267794 14.27839178  0.         14.27502707 14.25460551]

# %%
print("./results"+directoryN)
# Out:
# ./results/testPhoto2/success/

# %%
testtest=testPsoil
#testtest= testPsoiLight
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,2, sharey=False)
axs[0, 0].plot(testtest[:len(Ev)], Ev, 'b+')
axs[0, 0].set(xlabel='Ψsoil (cm)', ylabel='total E (cm3/d)')
axs[0, 1].plot(testtest[:len(loop)], loop,'+')
axs[0, 1].set(xlabel='Ψsoil (cm)', ylabel='loop')
axs[1, 0].plot(testtest[:len(Vcrate)], Vcrate, 'g+')
axs[1, 0].plot(testtest[:len(Vjrate)], Vjrate, 'r+')
axs[1,0].plot(testtest[:len(Anrate)],np.array(Anrate),'+')
axs[1, 0].set(xlabel='Ψsoil (cm)', ylabel='An, Vc, Vj mumol m-2 s-1')
axs[1, 1].plot(testtest[:len(pg)], pg, 'g+')
axs[1, 1].set(xlabel='Ψsoil (cm)', ylabel='pg')
plt.show()

# %%
fig, axs = plt.subplots(2,2, sharey=False)
axs[0,0].plot(testtest[:len(gco2)], gco2, 'b+')
axs[0,0].set(xlabel='Ψsoil (cm)', ylabel='gco2')
axs[0,1].plot(testtest[:len(fw)], fw, 'b+')
axs[0,1].set(xlabel='Ψsoil (cm)', ylabel='fw')
axs[1, 0].plot(testtest[:len(fwold)], np.array(ci)/r.cs, 'r+')
axs[1, 0].set(xlabel='Ψsoil (cm)', ylabel='ci')
axs[1,1].plot(testtest[:len(fwVold)],np.array(EvRate)*1000 *18/1000 * 24. * 3600 * 1e-4, 'g+')
axs[1, 1].set(xlabel='Ψsoil (cm)', ylabel='EvRate mmol m-2 s-1')
plt.show()

# %%
print(max(np.array(ci)/r.cs))
# Out:
# 0.8177874182675826

# %%
weatherX['RH']
# Out:
# 0.3081778016906361

# %%
Ev
# Out:
# [2.9566550031436645,
#  2.9507043279008114,
#  2.9507736234864557,
#  2.95078639428835,
#  2.95078522710661,
#  2.950785275535448,
#  2.950785277013792,
#  2.9507852799697787,
#  2.9507852752134918,
#  2.950785276851583,
#  2.950785274769071,
#  2.9507852792411287,
#  2.9507852735552507,
#  2.9507852753853627,
#  2.9507852744623957,
#  2.9507852721644343,
#  2.950785272951345,
#  2.9507852719188166,
#  2.95078528393055,
#  2.9507852720306107,
#  2.950785274932206,
#  2.9507852681455637,
#  2.9507852748656997,
#  2.950785276545516,
#  2.9507852744699967,
#  2.950785270712193,
#  2.950785278412878,
#  2.9507852723529044,
#  2.950785277171726,
#  2.950785272712238,
#  2.9507852762597113,
#  2.9507852714541305,
#  2.9507852694840704,
#  2.950785275597718,
#  2.9507852761445883,
#  2.950785270724003,
#  2.950785286971539,
#  2.9507852728229826,
#  2.950785278625193,
#  2.9507852768132743,
#  2.9507852737203595,
#  2.950785275602288,
#  2.950785270047756,
#  2.95078527256918,
#  2.95078527075662,
#  2.9507852737488123,
#  2.9507852742007317,
#  2.9507852732394046,
#  2.950785276335562,
#  2.950785274917987,
#  2.950785274216395,
#  2.9507852782116566,
#  2.950785275428676,
#  2.9507852695317043,
#  2.950785278238414,
#  2.950785275452795,
#  2.950785273373788,
#  2.9507852800723815,
#  2.950785276061587,
#  2.9507852739073472,
#  2.9507852785861695,
#  2.9507852794418485,
#  2.9507852766300617,
#  2.950785274759526,
#  2.9507852742199217,
#  2.950785281701744,
#  2.9507852680868893,
#  2.950785275829433,
#  2.9507852799713272,
#  2.95078527572807,
#  2.9507852697220374,
#  2.950785274982732,
#  2.950785271106728,
#  2.950785275354819,
#  2.950785263366553,
#  2.9507852772705716,
#  2.9507852744217398,
#  2.9507852730288526,
#  2.9507852735230333,
#  2.950785276633474,
#  2.950785274357084,
#  2.95078527597949,
#  2.950785278095506,
#  2.950785283009514,
#  2.9507852766055196,
#  2.9507852785924547,
#  2.9507852738035436,
#  2.950785269720523,
#  2.950785273010916,
#  2.9507852719312075,
#  2.9507852757875304,
#  2.9507852725584045,
#  2.9507852650426876,
#  2.9507852749156194,
#  2.9507852753302126,
#  2.950785273630172,
#  2.9507852775207617,
#  2.9507852769697895,
#  2.9507852703973487,
#  2.9507852777644987,
#  2.9507852717666414,
#  2.950785270123525,
#  2.950785272802289,
