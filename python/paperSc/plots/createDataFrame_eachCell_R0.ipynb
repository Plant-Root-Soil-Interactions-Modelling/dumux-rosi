# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pathresults = "../results/"
#pathresults = "/DUMUXDune27/DUMUX/dumux-rosi/python/paperSc/results/"
data_file_delimiter = ","
import re

# %%
def getVal(mypath, filename, header="infer",names = None):
    fullpath = pathresults +mypath+filename
    if names is None:
        cst = pd.read_csv(fullpath,delimiter=data_file_delimiter, header = header).dropna(how= "all", axis=1)
    else:
        cst = pd.read_csv(fullpath,delimiter=data_file_delimiter, header = header, names = names).dropna(how= "all", axis=1)
    return cst
def get_last_line_as_numpy_array(file_path, dtype = float):
    with open(pathresults +file_path, 'r') as file:
        # Read all lines
        lines = file.readlines()

        # Check if there are any lines in the file
        if not lines:
            raise ValueError("The file is empty")

        # Get the last line
        last_line = lines[-1].strip()

        # Split the last line by commas and convert to NumPy array
        array_from_last_line = np.array(last_line.split(','), dtype=dtype)

        return array_from_last_line

def list_files_with_prefix(folder_path, prefix):
    file_names = []
    for file_name in os.listdir(pathresults+folder_path):
        if file_name.startswith(prefix):
            file_names.append(file_name)
    return file_names
def getCylIdx(folder_path):
    namelist = list_files_with_prefix(folder_path+"cyl_val/", "Cyl_watercontent_")
    idxlist = np.full(len(namelist),-1,dtype = int)
    for nn, nl in enumerate(namelist):
        match = re.search(r'\d+', nl)
        number_str = match.group()
        number_int = int(number_str)
        idxlist[nn] = number_int
    return idxlist
# cylinder max konz (per cell)
def getData_(cid,gId,path2file):
    fileName = "cyl_val/Cyl_cellVol_"+str(gId)+".txt"
    cVol = get_last_line_as_numpy_array(path2file+fileName, dtype = float)
    if cid == volIdx:
        return cVol
    elif cid <= 9:
        if cid <= 2:# == 0:
            fileName = "cyl_val/Cyl_watercontent_"+str(gId)+".txt"
            theta = get_last_line_as_numpy_array(path2file+fileName, dtype = float)
            cVol *= theta#cm3 scv to cm3 water
            if cid == 0:
                return cVol
        fileName = "cyl_val/Cyl_content"+str(cid)+"_"+str(gId)+".txt"
        Q1 = get_last_line_as_numpy_array(path2file+fileName, dtype = float)
        konz = Q1/cVol #mol/cm3 or cm3/cm3
        return konz
    raise Exception

numPset = 99
nKonz = 9
dictXYZ = {9:'X',10:'Y',11:'Z'}
volIdx=12
lenIdx=13
relLenId=14
coordId = 15
nToGet = coordId+1 #elements + 3d coordinates of y , node+vol+len+st 

exceptPset =[12, 13, 20, 22, 32, 39, 44, 61, 66, 67, 91]
allPSets = [ i for i in range(numPset) if i not in exceptPset]

def getData():
    GiniAll = [[[] for i in range(numPset)] for ii in range(nToGet)]
    for pSet in allPSets:# range(numPset):
        print(pSet,end =", ")

        #path2file = 'none_55_'+str(pSet)+'_10to11_20mn_0s_5/'
        path2file = '1d1dFHungnone_1440_'+str(pSet)+'_10to25_20mn_0s_128/'
        
        #rr = getCylIdx(path2file)
        orgidPerNode = get_last_line_as_numpy_array(path2file+"orgidPerNode.txt", dtype =int)
        globalNodeId = get_last_line_as_numpy_array(path2file+"globalNodeId.txt", dtype =int)
        rr = globalNodeId[orgidPerNode == 1]-1 # node to segid
        rr = rr[1:]# take out base node
        rr.sort()
        print('(',len(rr),')',end =", ")

        for cid in range(nKonz):
            Ginits = np.array([getData_( cid, gId,path2file) for gId in rr])          
            GiniAll[cid][pSet] = Ginits
        for cid in range(nKonz,volIdx):
            nodes_ =get_last_line_as_numpy_array(path2file+"nodes_"+dictXYZ[cid]+".txt", dtype =float)
            GiniAll[cid][pSet] = nodes_[rr+1]#seg idx to y-idx
            
        GiniAll[volIdx][pSet] = np.array([getData_( volIdx, gId,path2file) for gId in rr])
        
        lens = get_last_line_as_numpy_array(path2file+"length_Segs"+".txt", dtype =float)
        GiniAll[lenIdx][pSet] = lens[rr]
        
        GiniAll[relLenId][pSet] = np.cumsum(lens[rr])
        
        GiniAll[coordId][pSet]=np.array([get_last_line_as_numpy_array(path2file+"cyl_val/Cyl_coord_"+str(int(gId))+".txt", dtype =float) for gId in rr])

    return GiniAll #cid pSet rr

# %%
if False:
    pSet = 0
    GiniAll = [[[] for i in range(numPset)] for ii in range(nToGet)]
    path2file = 'none_55_'+str(pSet)+'_10to11_20mn_0s_5/'

    rr = getCylIdx(path2file)
    rr.sort()
    print('(',len(rr),')',end =", ")

    for cid in range(nKonz):
        Ginits = np.array([getData_( cid, gId,path2file) for gId in rr])          
        GiniAll[cid][pSet] = Ginits

# %%
GiniAll = getData()
# Out:
# 0,
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 GiniAll = getData()
#
# Cell In[6], line 80, in getData()
#      77 path2file = '1d1dFHungnone_1440_'+str(pSet)+'_10to25_20mn_0s_128/'
#      79 #rr = getCylIdx(path2file)
# ---> 80 orgidPerNode = get_last_line_as_numpy_array(path2file+"orgidPerNode.txt", dtype =int)
#      81 globalNodeId = get_last_line_as_numpy_array(path2file+"globalNodeId.txt", dtype =int)
#      82 rr = globalNodeId[orgidPerNode == 1]-1 # node to segid
#
# Cell In[6], line 9, in get_last_line_as_numpy_array(file_path, dtype)
#       8 def get_last_line_as_numpy_array(file_path, dtype = float):
# ----> 9     with open(pathresults +file_path, 'r') as file:
#      10         # Read all lines
#      11         lines = file.readlines()
#      13         # Check if there are any lines in the file
#
# File ~/.conda/envs/py38b/lib/python3.8/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/1d1dFHungnone_1440_0_10to25_20mn_0s_128/orgidPerNode.txt'

# %%
#DumuxDune27/DUMUX/dumux-rosi/python/paperSc/results/1d1dFHungnone_1440_5_10to25_20mn_0s_128/orgidPerNode.txt
df = pd.DataFrame(GiniAll)

# %%
df.to_pickle('./cyl10to11R0.pkl')

# %%
df[0][0] #print(len(GiniAll),len(GiniAll[0]),len(GiniAll[0][0]),len(GiniAll[0][0]))
# Out:
# array([[0.00084606, 0.00121751, 0.00175206, ..., 0.00751354, 0.01081232,
#         0.01555942],
#        [0.00014654, 0.0002118 , 0.00030613, ..., 0.00133594, 0.0019309 ,
#         0.00279081],
#        [0.0001468 , 0.00021757, 0.00032246, ..., 0.00155591, 0.00230601,
#         0.00341774],
#        ...,
#        [0.00033875, 0.00071161, 0.0014949 , ..., 0.02911327, 0.06115902,
#         0.12847851],
#        [0.00020359, 0.00033441, 0.00054928, ..., 0.00399826, 0.00656733,
#         0.01078717],
#        [0.00091615, 0.00135783, 0.00201244, ..., 0.00971033, 0.01439169,
#         0.02132992]])

# %%
# get param set
paramsets =  pd.read_csv('../output_random_rows.csv')
paramsets = paramsets.drop(paramsets.columns.tolist()[-1],axis=1)
paramsets['k_C,S'] /=paramsets['theta']
paramsets['k_O,S'] /=paramsets['theta']
paramsets.drop(labels='theta', inplace=True, axis=1)
outputvalsname =  ['wat','cs','cl','coa','cod','cca','ccd','css2','co2','yX','yY','yZ','vol','lenSeg','st','orgId','relLen']
assert len(outputvalsname) == nToGet 
column_names = outputvalsname + paramsets.columns.tolist()+['pSet']
df = pd.DataFrame(columns=column_names)

for pset in range(numPset):
    N = GiniAll[0][pset].shape[0]
    #assert N == 232
    rows_to_duplicate_df = pd.DataFrame(paramsets.iloc[pset]).T
    duplicated_rows_df = rows_to_duplicate_df.loc[np.repeat(rows_to_duplicate_df.index.values, N)]
    # Duplicate the specific rows N times
    #print('init dupl row shape',duplicated_rows_df.shape)
    for jj, outVn in enumerate(outputvalsname):
        duplicated_rows_df[outVn] = GiniAll[jj][pset]
        #print('adding',jj,outVn,duplicated_rows_df.shape,len(GiniAll[jj][pset]))
    duplicated_rows_df['pSet'] = pset
    # Concatenate the original DataFrame with the duplicated specific rows
    df = pd.concat([df, duplicated_rows_df], ignore_index=True)
df['co'] = df['coa']+df['cod']
df['cc'] = df['cca']+df['ccd']

# %%
df
# Out:
#           wat            cs        cl           coa       cod           cca  \
# 0    0.049072  2.639671e-07  0.000906  9.085835e-08  0.000009  3.364929e-07
# 1    0.008728  2.438039e-07  0.000852  9.081024e-08  0.000009  3.363607e-07
# 2    0.010203  5.398630e-07  0.000925  9.154289e-08  0.000009  3.372123e-07
# 3    0.013479  2.466914e-07  0.000856  9.081228e-08  0.000009  3.363631e-07
# 4    0.010503  1.760157e-04  0.001104  8.208593e-06  0.000001  9.963765e-06
# ..        ...           ...       ...           ...       ...           ...
# 459  0.256344  4.608546e-06  0.000990  8.697761e-07  0.000008  6.688528e-07
# 460  0.018524  8.374195e-06  0.000990  1.087485e-06  0.000008  9.456851e-07
# 461  0.247872  3.999142e-06  0.000991  8.816617e-07  0.000008  6.063162e-07
# 462  0.035059  4.471629e-06  0.000991  9.133746e-07  0.000008  6.188445e-07
# 463  0.064446  4.948689e-06  0.000992  1.043685e-06  0.000008  6.393437e-07
#
#               ccd      css2           co2        yX  ...         Y       Y_C  \
# 0    8.915930e-06  0.000007  2.472739e-06 -0.298434  ...  0.234902  0.034053
# 1    8.915956e-06  0.000007  2.469714e-06  0.043922  ...  0.234902  0.034053
# 2    8.915583e-06  0.000007  2.483268e-06 -0.447197  ...  0.234902  0.034053
# 3    8.915956e-06  0.000007  2.469792e-06 -0.104340  ...  0.234902  0.034053
# 4    1.218063e-09  0.000061  2.295724e-05 -0.125120  ...  0.234902  0.034053
# ..            ...       ...           ...       ...  ...       ...       ...
# 459  8.575915e-06  0.000012  5.246680e-07  0.601310  ...  0.487350  0.173275
# 460  8.300378e-06  0.000012  5.334436e-07 -0.232992  ...  0.487350  0.173275
# 461  8.638386e-06  0.000012  5.242397e-07  0.738255  ...  0.487350  0.173275
# 462  8.625870e-06  0.000012  5.245975e-07  0.913513  ...  0.487350  0.173275
# 463  8.605875e-06  0.000012  5.285047e-07 -0.050663  ...  0.487350  0.173275
#
#           Y_O   CSS_max    k_sorp    CL_init   CS_init  pSet        co  \
# 0    0.469288  1.437543  0.039387  11.083551  0.006590     0  0.000009
# 1    0.469288  1.437543  0.039387  11.083551  0.006590     0  0.000009
# 2    0.469288  1.437543  0.039387  11.083551  0.006590     0  0.000009
# 3    0.469288  1.437543  0.039387  11.083551  0.006590     0  0.000009
# 4    0.469288  1.437543  0.039387  11.083551  0.006590     0  0.000010
# ..        ...       ...       ...        ...       ...   ...       ...
# 459  0.294169  1.421506  0.116672  11.870338  0.036058     1  0.000009
# 460  0.294169  1.421506  0.116672  11.870338  0.036058     1  0.000009
# 461  0.294169  1.421506  0.116672  11.870338  0.036058     1  0.000009
# 462  0.294169  1.421506  0.116672  11.870338  0.036058     1  0.000009
# 463  0.294169  1.421506  0.116672  11.870338  0.036058     1  0.000009
#
#            cc
# 0    0.000009
# 1    0.000009
# 2    0.000009
# 3    0.000009
# 4    0.000010
# ..        ...
# 459  0.000009
# 460  0.000009
# 461  0.000009
# 462  0.000009
# 463  0.000009
#
# [464 rows x 46 columns]

# %%
#df.to_pickle('./cyl10to11_allroots2.pkl')
