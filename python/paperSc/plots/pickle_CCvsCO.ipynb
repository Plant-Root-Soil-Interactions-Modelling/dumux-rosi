# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pathresults = "../results/"
#pathresults = "/DUMUXDune27/DUMUX/dumux-rosi/python/paperSc/results/"
data_file_delimiter = ","
import matplotlib.ticker as mtick
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns

# %%
df = pd.read_pickle("./cyl10to11.pkl") 
# get param set
paramsets =  pd.read_csv('../output_random_rows.csv')
paramsets = paramsets.drop(paramsets.columns.tolist()[-1],axis=1)
outputvalsname =  ['wat','cs','cl','coa','cod','cca','ccd','css2','co2','yX','yY','yZ']
column_names = outputvalsname + paramsets.columns.tolist()
#paramsets.drop(['theta','C_thres,O', 'CS_init', 'k_O,S', 'u_max,C', 'k_r,O'],inplace=True, axis=1)
#df.drop(['C_thres,O', 'CS_init', 'k_O,S', 'u_max,C', 'k_r,O'],inplace=True, axis=1)

# %%
repr(paramsets.columns.tolist())

# %%
outliers = np.array([[1, 8, 13, 14, 18, 26, 44, 51, 52, 62, 63, 64, 69, 72, 74, 78, 80, 83, 91, 92, 93] ])

# %%
unique_values = df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 99)
color_map = dict(zip(unique_values,rgb_values))

for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    col =color_map[value]
    edgecolors=  (0.0, 0.0, 0.0)
    if value == 5:
        col = (0.0, 0.0, 0.0)
        edgecolors=  (1,1,1)
    plt.scatter(subset['cc'], subset['co'], alpha=0,#0.3, 
                c = col #color_map[value]
               )
for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    col =color_map[value]
    edgecolors=  (0.0, 0.0, 0.0)
    if value == 5:
        col = (0.0, 0.0, 0.0)
        edgecolors=  (1,1,1)
    plt.scatter(subset['cc'], subset['co'], alpha=0.3, 
                c = col #color_map[value]
               )

for value in [5]:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    col =color_map[value]
    edgecolors=  (0.0, 0.0, 0.0)
    if value == 5:
        col = (0.0, 0.0, 0.0)
        edgecolors=  (1,1,1)
    plt.scatter(subset['cc'], subset['co'], alpha=1, 
                c = col ,zorder=100#color_map[value]
               )
# Add labels and legend
plt.xlabel('cc (mol/cm3)')
plt.ylabel('co (mol/cm3)')

plt.show()
# Out:
# /tmp/ipykernel_108/2002776414.py:12: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(subset['cc'], subset['co'], alpha=0,#0.3,
# /tmp/ipykernel_108/2002776414.py:22: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(subset['cc'], subset['co'], alpha=0.3,
# /tmp/ipykernel_108/2002776414.py:33: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(subset['cc'], subset['co'], alpha=1,

# %%
unique_values = [5]#df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 99)
color_map = dict(zip(unique_values,rgb_values))

for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    col =color_map[value]
    edgecolors=  (0.0, 0.0, 0.0)
    if value == 5:
        col = (0.0, 0.0, 0.0)
        edgecolors=  (1,1,1)
    plt.scatter(subset['cc'], subset['co'], alpha=0.3, 
                c = col #color_map[value]
               )

# Add labels and legend
plt.xlabel('cc (mol/cm3)')
plt.ylabel('co (mol/cm3)')

plt.show()
# Out:
# /tmp/ipykernel_108/3147370408.py:12: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(subset['cc'], subset['co'], alpha=0.3,

# %%
color_map[0]
# Out:
# (0.4, 0.7607843137254902, 0.6470588235294118)

# %%
unique_values =[74]# df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 99)
color_map = dict(zip(unique_values,rgb_values))

for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter(subset['cc'], subset['co'], alpha=0.3, 
                c = color_map[value])

# Add labels and legend
plt.xlabel('cc (mol/cm3)')
plt.ylabel('co (mol/cm3)')

plt.show()

# %%
unique_values = df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 2)
color_map = dict(zip([0,1],rgb_values))

for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter(subset['cc'], subset['co'], alpha=0.3, 
                c = color_map[(value in outliers)])

# Add labels and legend
plt.xlabel('cc')
plt.ylabel('co')

plt.show()

# %%
unique_values = df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 2)
color_map = dict(zip([0,1],rgb_values))

for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter(subset['coa'], subset['cod'], alpha=0.3, 
                c = color_map[(value in outliers)])

# Add labels and legend
plt.xlabel('coa')
plt.ylabel('cod')

plt.show()

# %%
unique_values = df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 99)
color_map = dict(zip(unique_values,rgb_values))


for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter(subset['cca'], subset['coa'], alpha=0.3, 
                c =  color_map[value])#color_map[(value in outliers)])

# Add labels and legend
plt.xlabel('cca')
plt.ylabel('coa')

plt.show()

# %%
unique_values = df['pSet'].unique()
rgb_values = sns.color_palette("Set2", 2)
color_map = dict(zip([0,1],rgb_values))

for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter(subset['cca'], subset['coa'], alpha=0.3, 
                c =  color_map[(value == 12)])

# Add labels and legend
plt.xlabel('cca')
plt.ylabel('coa')

plt.show()

# %%
df[['cca','pSet']].sort_values('cca', ascending = False).head(10)

# %%
unique_values = df['pSet'].unique()
for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter((subset['cc']),(subset['co']), #np.log(df['cc']),np.log(df['co']), 
                #c=df[nn],
                alpha=0.3, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    plt.title(value)
    plt.colorbar()
    plt.xlabel('copiotrophe (mol/cm3)')
    plt.ylabel('oligotrophe (mol/cm3)')
    plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
    plt.show()

# %%
plt.scatter((df['cc']),(df['co']), #np.log(df['cc']),np.log(df['co']), 
            c=df[nn],
            alpha=0.3, edgecolors ='none')
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
plt.title(nn)
plt.colorbar()
plt.xlabel('copiotrophe (mol/cm3)')
plt.ylabel('oligotrophe (mol/cm3)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()

# %%
for nn in paramsets.columns.tolist():
    plt.scatter((df['cc']),(df['co']), #np.log(df['cc']),np.log(df['co']), 
                c=df[nn],
                alpha=0.3, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    plt.title(nn)
    plt.colorbar()
    plt.xlabel('cc (mol/cm3)')
    plt.ylabel('co (mol/cm3)')
    plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
    plt.show()

# %%
for nn in paramsets.columns.tolist():
    plt.scatter((df['cc']),(df['co']), #np.log(df['cc']),np.log(df['co']), 
                c=df[nn],
                alpha=0.3, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    plt.title(nn)
    plt.colorbar()
    plt.xlabel('co (mol/cm3)')
    plt.ylabel('cc (mol/cm3)')
    #plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    #plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
    plt.show()

# %%
for nn in paramsets.columns.tolist():
    plt.scatter(df[nn],(df['cc'])/(df['co']), #np.log(df['cc']),np.log(df['co']), 
                #c=df[nn],
                alpha=0.3, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    plt.title(nn)
    plt.colorbar()
    plt.xlabel('copiotrophe (mol/cm3)')
    plt.ylabel('oligotrophe (mol/cm3)')
    plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
    plt.show()

# %%
plt.scatter((df['co']),(df['co'])/df['cc'], #np.log(df['cc']),np.log(df['co']), 
            c=df['pSet'],
            alpha=0.3, edgecolors ='none')
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('copiotrophe (mol/cm3)')
plt.ylabel('oligotrophe (mol/cm3)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()

# %%
plt.scatter((df['cc']),(df['co'])/df['cc'], #np.log(df['cc']),np.log(df['co']), 
            #c=df['pSet'],
            alpha=0.3, edgecolors ='none')

subset = df[df['pSet'] == 5]  # Select subset where 'pSet' equals the current value
col = (0.0, 0.0, 0.0)
plt.scatter((subset['cc']),(subset['co'])/subset['cc'], alpha=1, 
            c = col ,zorder=100#color_map[value]
           )
    
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('cc (mol/cm3)')
plt.ylabel('co/cc (-)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipykernel_108/3103698217.py:7: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter((subset['cc']),(subset['co'])/subset['cc'], alpha=1,

# %%
plt.scatter((df['cc']),(df['cca'])/df['cc'], #np.log(df['cc']),np.log(df['co']), 
            c=df['pSet'],
            alpha=0.3, edgecolors ='none')

subset = df[df['pSet'] == 5]  # Select subset where 'pSet' equals the current value
col = (0.0, 0.0, 0.0)
plt.scatter((subset['cc']),(subset['cca'])/subset['cc'], alpha=1, 
            c = col ,zorder=100#color_map[value]
           )
    
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('cc (mol/cm3)')
plt.ylabel('cca/cc (-)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipykernel_108/991374248.py:7: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter((subset['cc']),(subset['cca'])/subset['cc'], alpha=1,

# %%
plt.scatter((df['cc']),(df['ccd'])/df['cc'], #np.log(df['cc']),np.log(df['co']), 
            #c=df['pSet'],
            alpha=0.3, edgecolors ='none')

subset = df[df['pSet'] == 5]  # Select subset where 'pSet' equals the current value
col = (0.0, 0.0, 0.0)
plt.scatter((subset['cc']),(subset['ccd'])/subset['cc'], alpha=1, 
            c = col ,zorder=100#color_map[value]
           )

plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('cc (mol/cm3)')
plt.ylabel('ccd/cc (-)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipykernel_108/3853559095.py:7: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter((subset['cc']),(subset['ccd'])/subset['cc'], alpha=1,

# %%
plt.scatter((df['co']),(df['cod'])/df['co'], #np.log(df['cc']),np.log(df['co']), 
            #c=df['pSet'],
            alpha=0.3, edgecolors ='none')

subset = df[df['pSet'] == 5]  # Select subset where 'pSet' equals the current value
col = (0.0, 0.0, 0.0)
plt.scatter((subset['co']),(subset['cod'])/subset['co'], alpha=1, 
            c = col ,zorder=100#color_map[value]
           )

plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('co (mol/cm3)')
plt.ylabel('cod/co (-)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipykernel_108/2688928898.py:7: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter((subset['co']),(subset['cod'])/subset['co'], alpha=1,

# %%
unique_values = df['pSet'].unique()
if True:#for value in unique_values:
    subset = df#[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter((subset['ccd'])/subset['cc'],(subset['cod'])/subset['co'], #np.log(df['cc']),np.log(df['co']), 
                c=(subset['cc']+subset['co']*0)*subset['vol'],
                alpha=0.1, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    plt.title('microbial content')
    #plt.title('cs')
    plt.colorbar()
    plt.xlabel('ccd/cc (-)')
    plt.ylabel('cod/co (-)')
    plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
plt.show()

# %%
def scatter_hist(x, y,sets, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y,
               #c=df['vol'],
               alpha=0.3, edgecolors ='none')

    is5x = x[np.where(sets == 5)[0] ] # Select subset where 'pSet' equals the current value
    is5y = y[np.where(sets == 5)[0] ] # Select subset where 'pSet' equals the current value
    col = (0.0, 0.0, 0.0)
    ax.scatter(is5x, is5y, alpha=1, 
                c = col ,zorder=100#color_map[value]
               )
    # now determine nice limits by hand:
    binwidth = 0.05
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')
# Start with a square Figure.
fig = plt.figure(figsize=(6, 6))
# Add a gridspec with two rows and two columns and a ratio of 1 to 4 between
# the size of the marginal axes and the main axes in both directions.
# Also adjust the subplot parameters for a square plot.
gs = fig.add_gridspec(2, 2,  width_ratios=(4, 1), height_ratios=(1, 4),
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)
# Create the Axes.
ax = fig.add_subplot(gs[1, 0])
ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)
ax.set_xlabel('ccd/cc (-)')
ax.set_ylabel('cod/co (-)')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
# Draw the scatter plot and marginals.
scatter_hist((df['ccd'])/df['cc'],(df['cod'])/df['co'], df['pSet'], ax, ax_histx, ax_histy)
# Out:
# /tmp/ipykernel_108/155724832.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(is5x, is5y, alpha=1,

# %%
np.where(df['pSet'] == 5)
# Out:
# (array([1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196,
#         1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207,
#         1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218,
#         1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229,
#         1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240,
#         1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251,
#         1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262,
#         1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273,
#         1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284,
#         1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295,
#         1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306,
#         1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317,
#         1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328,
#         1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339,
#         1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350,
#         1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361,
#         1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372,
#         1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383,
#         1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394,
#         1395, 1396, 1397, 1398, 1399, 1400, 1401]),)

# %%
for nn in paramsets.columns.tolist():
    subset = df#[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter((subset['ccd'])/subset['cc'],(subset['cod'])/subset['co'], #np.log(df['cc']),np.log(df['co']), 
                c=df['pSet'],
                alpha=0.3, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    plt.title(nn)
    plt.colorbar()
    plt.xlabel('ccd/cc (mol/cm3)')
    plt.ylabel('cod/co (-)')
    plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
    plt.show()

# %%
unique_values = df['pSet'].unique()
for value in unique_values:
    subset = df[df['pSet'] == value]  # Select subset where 'pSet' equals the current value
    plt.scatter((subset['ccd'])/subset['cc'],(subset['cod'])/subset['co'], #np.log(df['cc']),np.log(df['co']), 
                #c=df['pSet'],
                alpha=0.3, edgecolors ='none')
    plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
    #plt.title(nn)
    #plt.colorbar()
    plt.xlabel('ccd/cc (mol/cm3)')
    plt.ylabel('cod/co (-)')
    plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
    plt.xticks(rotation=30)
plt.show()

# %%
plt.scatter((df['co']),(df['co'])/df['cc'], #np.log(df['cc']),np.log(df['co']), 
            c=df['pSet'],
            alpha=0.3, edgecolors ='none')
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('co (mol/cm3)')
plt.ylabel('co/cc (mol/cm3)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()

# %%
plt.scatter((df['cod']),(df['ccd'])/df['cod'], #np.log(df['cc']),np.log(df['co']), 
            c=df['pSet'],
            alpha=0.3, edgecolors ='none')
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('cod (mol/cm3)')
plt.ylabel('ccd/cod (-)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()

# %%
plt.scatter((df['coa']),(df['cca'])/df['coa'], #np.log(df['cc']),np.log(df['co']), 
            c=df['pSet'],
            alpha=0.3, edgecolors ='none')
plt.rcParams.update({'figure.figsize':(5,5), 'figure.dpi':100})
#plt.title(nn)
#plt.colorbar()
plt.xlabel('coa (mol/cm3)')
plt.ylabel('cca/coa (-)')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.gca().xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.xticks(rotation=30)
plt.show()

# %%
df['cc_co']=df['cc']/df['co']

# %%
# won t do. i ll stick to parametrique tests
#model = smf.ols(formula='cc_co ~ beta_C * beta_O * C_thres,C * DS_W * k_C,S * k_d,C * k_d,O * K_L * k_r,C * m_max,C * m_max,O * p_L * ro_B * u_max,O * v_max,L * Y * Y_C * Y_O * CSS_max * k_sorp * CL_init', data=df).fit()
#model.summary()

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
features =paramsets.columns.tolist()
x =df.loc[:, features].values
# Separating out the target
y = df.loc[:,['cc_co']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
repr(paramsets.columns.tolist())

# %%
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['cc_co']]], axis = 1)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

ax.scatter(finalDf[ 'principal component 1']
               , finalDf[ 'principal component 2']
               , c = finalDf[ 'cc_co']
               , s = 50)
#ax.legend(targets)
ax.grid()

# %%
len(finalDf[ 'cc_co'])

# %%
pca.explained_variance_ratio_

# %%
features = paramsets.columns.tolist()+[ 'cc_co']
dftemp = df.loc[:, features]
corr_matrix = dftemp.corr()['cc_co']

# %%
corr_matrix

# %%
features = paramsets.columns.tolist()+[ 'cc_co']
dftemp = np.log(df.loc[:, features])
corr_matrix = dftemp.corr()['cc_co']
corr_matrix
